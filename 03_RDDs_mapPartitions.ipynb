# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql import Row
import fasttext

# %%
spark = SparkSession.builder.appName('mysession').getOrCreate()

# %% [markdown]
# ## Build Spark DataFrame

# %%
df_input = spark.read.parquet('data/input.parquet').repartition(20)

# %% [markdown]
# # Approach 3: RDD's mapPartitions

# %%
def fn_partition(iterator,multi_prediction=False):
    
    def get_predictions(sentence,threshold=0.10,k=3):
        '''
        Function to get a list with predictions for a sentence, given a fastText model
        and given one of: a probability threshold, or a desired number k of top-k predictions.
        '''
        if threshold:
            labels, probs = model.predict(sentence.lower(),k=k)
            candidates = map(lambda y: y[0], filter(lambda x: x[1] >= threshold, zip(labels, probs)))
        else:
            candidates = model.predict(sentence.lower(),k=k)[0]
        output = list(map(lambda x: x.replace("__label__",""), candidates))
        if len(output)==0:
            return None
        else:
            return output[0] if k==1 else output
    
    model = fasttext.load_model('models/ft_tuned.ftz')
    
    for record in iterator:
        if not multi_prediction:
            yield Row(category=get_predictions(record['input'],k=1),input=record['input'])
        else: 
            yield Row(category=get_predictions(record['input'],k=3),input=record['input'])

# %% [markdown]
# ## Single prediction

# %%
df_output = df_input.rdd.mapPartitions(lambda partition: fn_partition(partition,False)).toDF()
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------+----------------------------------------------------------------------------------------------+
# |category  |input                                                                                         |
# +----------+----------------------------------------------------------------------------------------------+
# |sql-server|how do i set a sql server script s timeout from within the script                             |
# |.net      |embedding intellisense xml documentation in assembly                                          |
# |asp.net   |css `` see through '' background crazy navigation menu problem                                |
# |c#        |add custom textboxcell to a datagridview control that contains a button to open the filedialog|
# |c#        |how do you bind in xaml to a dynamic xpath                                                    |
# |java      |using noweb on a large java project                                                           |
# |null      |how do i slice an array in excel vba                                                          |
# |asp.net   |classic asp intranet and new asp net applications                                             |
# |null      |drawing a custom label on a pie chart in yahoo s flash library astra                          |
# |c#        |how do i add html links in c # textbox                                                        |
# +----------+----------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Multiple prediction

# %%
df_output = df_input.rdd.mapPartitions(lambda partition: fn_partition(partition,True)).toDF()
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------------------+----------------------------------------------------------------------------------------------+
# |category              |input                                                                                         |
# +----------------------+----------------------------------------------------------------------------------------------+
# |[sql-server, sql]     |how do i set a sql server script s timeout from within the script                             |
# |[.net, c#]            |embedding intellisense xml documentation in assembly                                          |
# |[asp.net]             |css `` see through '' background crazy navigation menu problem                                |
# |[c#, .net]            |add custom textboxcell to a datagridview control that contains a button to open the filedialog|
# |[c#]                  |how do you bind in xaml to a dynamic xpath                                                    |
# |[java]                |using noweb on a large java project                                                           |
# |null                  |how do i slice an array in excel vba                                                          |
# |[asp.net, asp.net-mvc]|classic asp intranet and new asp net applications                                             |
# |null                  |drawing a custom label on a pie chart in yahoo s flash library astra                          |
# |[c#]                  |how do i add html links in c # textbox                                                        |
# +----------------------+----------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# # Performance

# %%
# %timeit -n 10 df_output.sample(False,.10).show(10,False)
# Out:
# +-------------------------+--------------------------------------------------------------------+
# |category                 |input                                                               |
# +-------------------------+--------------------------------------------------------------------+
# |[c#]                     |c # 4 0 feedback                                                    |
# |[asp.net, c#, .net]      |how do i update a gridview from a page method from code behind      |
# |null                     |game programming and event handlers                                 |
# |null                     |regex to match against something that is not a specific substring   |
# |[css, html, asp.net]     |css and lack of constants/variables issue                           |
# |null                     |std wcout to console window in xcode                                |
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008            |
# |null                     |what s the best way to get started with osgi                        |
# |[c#, .net]               |is it possible to view all services/types registered to structuremap|
# |null                     |perform token replacements using vs post build event command        |
# +-------------------------+--------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+----------------------------------------------------------------------+
# |category           |input                                                                 |
# +-------------------+----------------------------------------------------------------------+
# |[asp.net]          |asp net ajax textbox readonly state                                   |
# |[.net, wpf]        |is wpf production ready                                               |
# |null               |how do i add custom column to existing wss list template              |
# |[java]             |saving java object graphs as xml file                                 |
# |[c++]              |using boost shared_ptr in a library s public interface                |
# |[.net, c#, asp.net]|is filestream lazy loaded in net                                      |
# |[asp.net]          |using server side xml parser to generate html content                 |
# |[java]             |how do i skip items when tabbing without using tabindex               |
# |[c++]              |why does the bitconverter return bytes and how can i get the bits then|
# |[java]             |how to do unit testing with uncertainties                             |
# +-------------------+----------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+------------------------------------------------------------------------------------------+
# |category           |input                                                                                     |
# +-------------------+------------------------------------------------------------------------------------------+
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''                     |
# |[c#]               |use type of object in hql where clause                                                    |
# |null               |how can i show scrollbars on a system windows forms textbox only when the text doesn t fit|
# |[c#, c++]          |how do i find the type of the object instance of the caller of the current function       |
# |null               |how to unit test an object with database queries                                          |
# |[sql-server, sql]  |custom aggregate functions in ms sql server                                               |
# |[c#]               |can garbage collection coexist with explicit memory management                            |
# |[php]              |php function which does syntax color parsing for multiple languages                       |
# |null               |delphi project needing runtime packages even with runtime packages off                    |
# |[c, c#, c++]       |wrapping visual c++ in c #                                                                |
# +-------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +------------------------+-----------------------------------------------------------------------------+
# |category                |input                                                                        |
# +------------------------+-----------------------------------------------------------------------------+
# |[ruby, ruby-on-rails]   |what are the limits of ruby on rails                                         |
# |[asp.net]               |using server side xml parser to generate html content                        |
# |[.net]                  |how does one add a custom build step to an automake based project in kdevelop|
# |null                    |clean document roles in a doc library                                        |
# |[c#, .net]              |creating my own iterators                                                    |
# |[jquery, javascript]    |vertical text with jquery                                                    |
# |[sql, mysql, sql-server]|how to efficiently sql select newest entries from a mysql database           |
# |null                    |how to move documents and list items in windows sharepoint services          |
# |[.net, c#]              |expose a specific net object as json                                         |
# |[sql, sql-server]       |select from same table as an insert or update                                |
# +------------------------+-----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |category              |input                                                                                                           |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |[c#]                  |use type of object in hql where clause                                                                          |
# |null                  |what is the best way to implement a singleton pattern class in actionscript 3                                   |
# |null                  |pexpect running ssh copy id is hanging when trying to spawn a second process                                    |
# |null                  |mssqlserver 2008 in virtual pc                                                                                  |
# |null                  |how to unit test an object with database queries                                                                |
# |null                  |std wcout to console window in xcode                                                                            |
# |[.net, c#]            |embedding intellisense xml documentation in assembly                                                            |
# |[php]                 |build tar file from directory in php without exec/passthru                                                      |
# |[asp.net-mvc, asp.net]|asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|
# |[.net, c#]            |expose a specific net object as json                                                                            |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +------------------------+------------------------------------------------------------------------------------------+
# |category                |input                                                                                     |
# +------------------------+------------------------------------------------------------------------------------------+
# |null                    |pexpect running ssh copy id is hanging when trying to spawn a second process              |
# |[sql, mysql, sql-server]|how to efficiently sql select newest entries from a mysql database                        |
# |[sql-server, sql]       |custom aggregate functions in ms sql server                                               |
# |[java]                  |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client|
# |[c#]                    |can garbage collection coexist with explicit memory management                            |
# |null                    |how to move documents and list items in windows sharepoint services                       |
# |[.net, c#]              |expose a specific net object as json                                                      |
# |null                    |what s all this business about flash flex adobe air java fx and silverlight               |
# |[c#]                    |how can i make a button like digg it for my website                                       |
# |null                    |how do i slice an array in excel vba                                                      |
# +------------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
# +-----------------------------+----------------------------------------------------------------------------------------------+
# |category                     |input                                                                                         |
# +-----------------------------+----------------------------------------------------------------------------------------------+
# |[c++]                        |using boost shared_ptr in a library s public interface                                        |
# |[java]                       |how do i skip items when tabbing without using tabindex                                       |
# |[c++]                        |why does the bitconverter return bytes and how can i get the bits then                        |
# |[c++]                        |can not execute program if using boost c++ libraries in debug version on winxp                |
# |[sql-server-2005, sql, mysql]|database schema design                                                                        |
# |null                         |google map overlay icon disappears at certain zoom level                                      |
# |null                         |how to move documents and list items in windows sharepoint services                           |
# |[java, c#]                   |two phase commit/shared transaction                                                           |
# |[c#, .net]                   |add custom textboxcell to a datagridview control that contains a button to open the filedialog|
# |[c#]                         |how do you bind in xaml to a dynamic xpath                                                    |
# +-----------------------------+----------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +--------------------+----------------------------------------------------------------------------+
# |category            |input                                                                       |
# +--------------------+----------------------------------------------------------------------------+
# |[asp.net]           |asp net ajax textbox readonly state                                         |
# |null                |how should i import highly formatted data from excel to a database          |
# |[java]              |saving java object graphs as xml file                                       |
# |[.net, c#, asp.net] |is filestream lazy loaded in net                                            |
# |null                |mssqlserver 2008 in virtual pc                                              |
# |null                |std wcout to console window in xcode                                        |
# |[java]              |unix socket implementation for java                                         |
# |[javascript, jquery]|most efficient way to close a load page using the x sign in jquery          |
# |[java]              |where did all the java applets go                                           |
# |[c#]                |in c # or any language what is/are your favourite way of removing repetition|
# +--------------------+----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------+-----------------------------------------------------------------------------------+
# |category         |input                                                                              |
# +-----------------+-----------------------------------------------------------------------------------+
# |[java]           |saving java object graphs as xml file                                              |
# |[c++]            |using boost shared_ptr in a library s public interface                             |
# |[c#, c++]        |how do i find the type of the object instance of the caller of the current function|
# |null             |center a block of content when you don t know its width in advance                 |
# |[java]           |when using ant how can i define a task only if i have some specific java version   |
# |[c#]             |how to implement a singleton in c #                                                |
# |[java]           |unix socket implementation for java                                                |
# |null             |how to force a redraw of my application s entry in the taskbar                     |
# |[javascript, php]|passing a value from php to javascript                                             |
# |[sql-server, sql]|custom aggregate functions in ms sql server                                        |
# +-----------------+-----------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------+---------------------------------------------------------------------------------+
# |category                 |input                                                                            |
# +-------------------------+---------------------------------------------------------------------------------+
# |[c#, java]               |equivalent of java s concurrenthashmap in c #                                    |
# |null                     |how do i add custom column to existing wss list template                         |
# |[c#, .net]               |whats the best way to start using mylyn                                          |
# |[asp.net]                |virtual directory in asp net project                                             |
# |[javascript]             |what is the best way to determine the number of days in a month with javascript  |
# |[jquery, javascript]     |vertical text with jquery                                                        |
# |[jquery, javascript]     |looping over elements in jquery                                                  |
# |[php]                    |a delphi/freepascal lib or function that emulates the php s function parse_url   |
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008                         |
# |[.net]                   |is it possible to set code behind a resource dictionary in wpf for event handling|
# +-------------------------+---------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------------+---------------------------------------------------------------------+
# |category                       |input                                                                |
# +-------------------------------+---------------------------------------------------------------------+
# |null                           |mssqlserver 2008 in virtual pc                                       |
# |[.net, c#, asp.net]            |sending email in net through gmail                                   |
# |[c#, .net]                     |how can i programmatically determine if my workstation is locked     |
# |[java]                         |how to do unit testing with uncertainties                            |
# |null                           |getting the last modified date of a html file                        |
# |[sql-server, linq-to-sql, linq]|another linq pivot problem convert sql script to linq                |
# |[php]                          |php function which does syntax color parsing for multiple languages  |
# |[sql-server, sql]              |bespoke sql server encoding sproc is there a neater way of doing this|
# |null                           |how do you design a functional program                               |
# |null                           |in mvc when do you use and                                           |
# +-------------------------------+---------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------+--------------------------------------------------------------------------------+
# |category                 |input                                                                           |
# +-------------------------+--------------------------------------------------------------------------------+
# |[c#, .net]               |whats the best way to start using mylyn                                         |
# |[asp.net]                |virtual directory in asp net project                                            |
# |[java]                   |when using ant how can i define a task only if i have some specific java version|
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008                        |
# |[java]                   |where did all the java applets go                                               |
# |[java]                   |jetty reload tag file in jar                                                    |
# |null                     |perform token replacements using vs post build event command                    |
# |null                     |delphi project needing runtime packages even with runtime packages off          |
# |[c, c#, c++]             |wrapping visual c++ in c #                                                      |
# |[asp.net]                |buttons in gridview control                                                     |
# +-------------------------+--------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------------+-----------------------------------------------------------------------------+
# |category                       |input                                                                        |
# +-------------------------------+-----------------------------------------------------------------------------+
# |[.net, c#, asp.net]            |any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''        |
# |null                           |what is the best way to implement a singleton pattern class in actionscript 3|
# |[c#, java]                     |equivalent of java s concurrenthashmap in c #                                |
# |[asp.net, c#, .net]            |how do i update a gridview from a page method from code behind               |
# |[jquery, javascript]           |looping over elements in jquery                                              |
# |[javascript, php]              |passing a value from php to javascript                                       |
# |[java]                         |find all drive letters in java                                               |
# |[sql-server, linq-to-sql, linq]|another linq pivot problem convert sql script to linq                        |
# |null                           |mvc preview 4 no route in the route table matches the supplied values        |
# |[java]                         |using noweb on a large java project                                          |
# +-------------------------------+-----------------------------------------------------------------------------+
# only showing top 10 rows
# +---------------------+----------------------------------------------------------------------------+
# |category             |input                                                                       |
# +---------------------+----------------------------------------------------------------------------+
# |[.net, c#, asp.net]  |any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''       |
# |[jquery, javascript] |vertical text with jquery                                                   |
# |[asp.net]            |css `` see through '' background crazy navigation menu problem              |
# |[javascript, php]    |passing a value from php to javascript                                      |
# |[visual-studio, .net]|how to get t4 files to build in visual studio                               |
# |[silverlight]        |silverlight databinding error works in wpf though                           |
# |[c#]                 |in c # or any language what is/are your favourite way of removing repetition|
# |null                 |what s the best way to get started with osgi                                |
# |[c#, .net]           |is it possible to view all services/types registered to structuremap        |
# |null                 |generating absolute urls from seam emails                                   |
# +---------------------+----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------+-----------------------------------------------------------------------------+
# |category                 |input                                                                        |
# +-------------------------+-----------------------------------------------------------------------------+
# |null                     |what is the best way to implement a singleton pattern class in actionscript 3|
# |[.net, c#, asp.net]      |sending email in net through gmail                                           |
# |null                     |center a block of content when you don t know its width in advance           |
# |[.net, c#]               |embedding intellisense xml documentation in assembly                         |
# |null                     |google map overlay icon disappears at certain zoom level                     |
# |null                     |insert dates in the return from a query where there is none                  |
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008                     |
# |[silverlight]            |silverlight databinding error works in wpf though                            |
# |[c#]                     |can garbage collection coexist with explicit memory management               |
# |null                     |mvc preview 4 no route in the route table matches the supplied values        |
# +-------------------------+-----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +---------------------+----------------------------------------------------------------------------+
# |category             |input                                                                       |
# +---------------------+----------------------------------------------------------------------------+
# |[ruby, ruby-on-rails]|what are the limits of ruby on rails                                        |
# |[c#]                 |c # 4 0 feedback                                                            |
# |[.net, c#]           |embedding intellisense xml documentation in assembly                        |
# |[java]               |unix socket implementation for java                                         |
# |[javascript, jquery] |most efficient way to close a load page using the x sign in jquery          |
# |[java]               |where did all the java applets go                                           |
# |[c#]                 |in c # or any language what is/are your favourite way of removing repetition|
# |[php]                |php function which does syntax color parsing for multiple languages         |
# |null                 |enabling controls at moment of opening a form in access                     |
# |null                 |how do i slice an array in excel vba                                        |
# +---------------------+----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +--------------------+------------------------------------------------------------------------------------------+
# |category            |input                                                                                     |
# +--------------------+------------------------------------------------------------------------------------------+
# |[sql-server, sql]   |how do i set a sql server script s timeout from within the script                         |
# |[c++]               |using boost shared_ptr in a library s public interface                                    |
# |[.net, c#, asp.net] |is filestream lazy loaded in net                                                          |
# |[c#, .net]          |creating my own iterators                                                                 |
# |[jquery, javascript]|looping over elements in jquery                                                           |
# |[.net, asp.net]     |vb net importing classes                                                                  |
# |[asp.net]           |css `` see through '' background crazy navigation menu problem                            |
# |[.net]              |is it possible to set code behind a resource dictionary in wpf for event handling         |
# |[java]              |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client|
# |[c#]                |in c # or any language what is/are your favourite way of removing repetition              |
# +--------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+---------------------------------------------------------------------------------------------+
# |category           |input                                                                                        |
# +-------------------+---------------------------------------------------------------------------------------------+
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''                        |
# |[.net, wpf]        |is wpf production ready                                                                      |
# |[c#, .net]         |is there a fast way to transfer all the variables of one identical object into another in c #|
# |[java]             |saving java object graphs as xml file                                                        |
# |[c++]              |can not execute program if using boost c++ libraries in debug version on winxp               |
# |[.net]             |is it possible to set code behind a resource dictionary in wpf for event handling            |
# |[javascript]       |actionscript3 to javascript communication best practices                                     |
# |[sql, sql-server]  |select from same table as an insert or update                                                |
# |null               |windows sharepoint services vs microsoft office sharepoint server                            |
# |[asp.net, c#]      |systemsounds play not working                                                                |
# +-------------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------------------+------------------------------------------------------------------+
# |category                     |input                                                             |
# +-----------------------------+------------------------------------------------------------------+
# |[sql-server, sql]            |how do i set a sql server script s timeout from within the script |
# |[c#, .net]                   |whats the best way to start using mylyn                           |
# |null                         |clean document roles in a doc library                             |
# |[java]                       |how to do unit testing with uncertainties                         |
# |[sql-server-2005, sql, mysql]|database schema design                                            |
# |[css, html, asp.net]         |css and lack of constants/variables issue                         |
# |null                         |std wcout to console window in xcode                              |
# |[c#]                         |how to implement a singleton in c #                               |
# |[javascript, jquery]         |most efficient way to close a load page using the x sign in jquery|
# |null                         |insert dates in the return from a query where there is none       |
# +-----------------------------+------------------------------------------------------------------+
# only showing top 10 rows
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |category              |input                                                                                                           |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |[c#]                  |use type of object in hql where clause                                                                          |
# |[c#, .net]            |is there a fast way to transfer all the variables of one identical object into another in c #                   |
# |null                  |async method call                                                                                               |
# |[c#, .net]            |how can i programmatically determine if my workstation is locked                                                |
# |[c#]                  |how to implement a singleton in c #                                                                             |
# |[java]                |find all drive letters in java                                                                                  |
# |[python]              |what fields should be indexed on a given table                                                                  |
# |[asp.net-mvc, asp.net]|asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|
# |[python]              |accessing python egg s own metadata                                                                             |
# |[sql-server, sql]     |best practice for graceful replace of read only sql server database                                             |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +---------------+---------------------------------------------------------------------------------------------+
# |category       |input                                                                                        |
# +---------------+---------------------------------------------------------------------------------------------+
# |[c#, .net]     |is there a fast way to transfer all the variables of one identical object into another in c #|
# |[c#, .net]     |how can i programmatically determine if my workstation is locked                             |
# |null           |how to unit test an object with database queries                                             |
# |[c#, c]        |is there an alternative for sleep in c                                                       |
# |[java]         |when using ant how can i define a task only if i have some specific java version             |
# |[.net, asp.net]|vb net importing classes                                                                     |
# |null           |getting the last modified date of a html file                                                |
# |[java]         |where did all the java applets go                                                            |
# |null           |tickmark algorithm for a graph axis                                                          |
# |null           |joins and where conditions                                                                   |
# +---------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +------------+----------------------------------------------------------------------------+
# |category    |input                                                                       |
# +------------+----------------------------------------------------------------------------+
# |[asp.net]   |asp net ajax textbox readonly state                                         |
# |null        |pexpect running ssh copy id is hanging when trying to spawn a second process|
# |[c#]        |c # 4 0 feedback                                                            |
# |[c++]       |using boost shared_ptr in a library s public interface                      |
# |[c#, c]     |is there an alternative for sleep in c                                      |
# |null        |google map overlay icon disappears at certain zoom level                    |
# |null        |what s the best way to get started with osgi                                |
# |[c, c#, c++]|wrapping visual c++ in c #                                                  |
# |[c++, c]    |initialize a const array in a class initializer in c++                      |
# |null        |generating absolute urls from seam emails                                   |
# +------------+----------------------------------------------------------------------------+
# only showing top 10 rows
#
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |category              |input                                                                                                           |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# |[ruby, ruby-on-rails] |what are the limits of ruby on rails                                                                            |
# |[asp.net]             |prevent long word to add horizontal scroll to html view                                                         |
# |null                  |pexpect running ssh copy id is hanging when trying to spawn a second process                                    |
# |[c++]                 |using boost shared_ptr in a library s public interface                                                          |
# |null                  |mssqlserver 2008 in virtual pc                                                                                  |
# |null                  |clean document roles in a doc library                                                                           |
# |[asp.net-mvc, asp.net]|asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|
# |[.net, c#]            |expose a specific net object as json                                                                            |
# |null                  |is there an idiomatic way to listen for changes to the dom using the prototype library                          |
# |null                  |how do you quickly find the url for a win32 api on msdn                                                         |
# +----------------------+----------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------+------------------------------------------------------------------------------------------+
# |category                 |input                                                                                     |
# +-------------------------+------------------------------------------------------------------------------------------+
# |[c++]                    |how to check if file is ascii or binary in c++                                            |
# |[c#]                     |use type of object in hql where clause                                                    |
# |[c#]                     |c # 4 0 feedback                                                                          |
# |[.net, c#, asp.net]      |is filestream lazy loaded in net                                                          |
# |null                     |clean document roles in a doc library                                                     |
# |[sql, mysql, sql-server] |how to efficiently sql select newest entries from a mysql database                        |
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008                                  |
# |[java]                   |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client|
# |[sql-server, sql]        |bespoke sql server encoding sproc is there a neater way of doing this                     |
# |null                     |is there a way to asynchronously filter an ilist                                          |
# +-------------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
# +--------------------+--------------------------------------------------------------------------------+
# |category            |input                                                                           |
# +--------------------+--------------------------------------------------------------------------------+
# |[asp.net]           |asp net ajax textbox readonly state                                             |
# |[asp.net]           |virtual directory in asp net project                                            |
# |[c#, c]             |is there an alternative for sleep in c                                          |
# |[java]              |when using ant how can i define a task only if i have some specific java version|
# |[jquery, javascript]|looping over elements in jquery                                                 |
# |[sql-server, sql]   |custom aggregate functions in ms sql server                                     |
# |[silverlight]       |silverlight databinding error works in wpf though                               |
# |null                |perform token replacements using vs post build event command                    |
# |[c++, c]            |initialize a const array in a class initializer in c++                          |
# |[.net, c#]          |custom properties in xaml of system windows window                              |
# +--------------------+--------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +------------+-------------------------------------------------------------------------------+
# |category    |input                                                                          |
# +------------+-------------------------------------------------------------------------------+
# |null        |what is the overhead cost associated with ioc containers like structuremap     |
# |[c#, java]  |equivalent of java s concurrenthashmap in c #                                  |
# |null        |pexpect running ssh copy id is hanging when trying to spawn a second process   |
# |[javascript]|what is the best way to determine the number of days in a month with javascript|
# |[c++]       |why does the bitconverter return bytes and how can i get the bits then         |
# |[asp.net]   |css `` see through '' background crazy navigation menu problem                 |
# |[python]    |what fields should be indexed on a given table                                 |
# |[c++]       |c++ reading from a file blocks any further writing why                         |
# |null        |how do you quickly find the url for a win32 api on msdn                        |
# |[c#, .net]  |read from msg files                                                            |
# +------------+-------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------------------+-----------------------------------------------------------------------------------+
# |category                     |input                                                                              |
# +-----------------------------+-----------------------------------------------------------------------------------+
# |[.net, wpf]                  |is wpf production ready                                                            |
# |[c++]                        |using boost shared_ptr in a library s public interface                             |
# |[c#, c++]                    |how do i find the type of the object instance of the caller of the current function|
# |[.net]                       |how does one add a custom build step to an automake based project in kdevelop      |
# |[java]                       |how do i skip items when tabbing without using tabindex                            |
# |[c++]                        |can not execute program if using boost c++ libraries in debug version on winxp     |
# |[sql-server-2005, sql, mysql]|database schema design                                                             |
# |null                         |std wcout to console window in xcode                                               |
# |[c#, .net]                   |creating my own iterators                                                          |
# |[sql, mysql, sql-server]     |how to efficiently sql select newest entries from a mysql database                 |
# +-----------------------------+-----------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +---------------------+---------------------------------------------------------------------------------------------+
# |category             |input                                                                                        |
# +---------------------+---------------------------------------------------------------------------------------------+
# |[ruby, ruby-on-rails]|what are the limits of ruby on rails                                                         |
# |null                 |what is the best way to implement a singleton pattern class in actionscript 3                |
# |[c#, .net]           |is there a fast way to transfer all the variables of one identical object into another in c #|
# |null                 |clean document roles in a doc library                                                        |
# |[javascript, jquery] |most efficient way to close a load page using the x sign in jquery                           |
# |[sql-server, sql]    |custom aggregate functions in ms sql server                                                  |
# |[visual-studio, .net]|how to get t4 files to build in visual studio                                                |
# |null                 |in mvc when do you use and                                                                   |
# |null                 |perform token replacements using vs post build event command                                 |
# |null                 |how new programming frameworks help analysts designers and programmers better work together  |
# +---------------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------+-----------------------------------------------------------------------------------+
# |category         |input                                                                              |
# +-----------------+-----------------------------------------------------------------------------------+
# |[php]            |how can i send an array to php through ajax                                        |
# |[c#, c++]        |how do i find the type of the object instance of the caller of the current function|
# |null             |center a block of content when you don t know its width in advance                 |
# |null             |clean document roles in a doc library                                              |
# |null             |how to unit test an object with database queries                                   |
# |[c#, .net]       |creating my own iterators                                                          |
# |[php]            |a delphi/freepascal lib or function that emulates the php s function parse_url     |
# |[.net, asp.net]  |vb net importing classes                                                           |
# |[sql-server, sql]|bespoke sql server encoding sproc is there a neater way of doing this              |
# |[c, c#, c++]     |wrapping visual c++ in c #                                                         |
# +-----------------+-----------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+---------------------------------------------------------------------+
# |category           |input                                                                |
# +-------------------+---------------------------------------------------------------------+
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''|
# |[asp.net]          |asp net ajax textbox readonly state                                  |
# |[java]             |saving java object graphs as xml file                                |
# |[c++]              |using boost shared_ptr in a library s public interface               |
# |[.net, c#, asp.net]|is filestream lazy loaded in net                                     |
# |null               |mssqlserver 2008 in virtual pc                                       |
# |[c#, .net]         |how can i programmatically determine if my workstation is locked     |
# |[c#, .net]         |whats the best way to start using mylyn                              |
# |null               |google map overlay icon disappears at certain zoom level             |
# |[javascript, php]  |passing a value from php to javascript                               |
# +-------------------+---------------------------------------------------------------------+
# only showing top 10 rows
# +-------------------+-------------------------------------------------------------------------------+
# |category           |input                                                                          |
# +-------------------+-------------------------------------------------------------------------------+
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''          |
# |[asp.net]          |asp net ajax textbox readonly state                                            |
# |[sql-server, sql]  |how do i set a sql server script s timeout from within the script              |
# |[c#, asp.net]      |sensitive data in viewstate                                                    |
# |[asp.net]          |virtual directory in asp net project                                           |
# |[javascript]       |what is the best way to determine the number of days in a month with javascript|
# |[php]              |a delphi/freepascal lib or function that emulates the php s function parse_url |
# ...
# only showing top 10 rows
#
# +-------------------+--------------------------------------------------------------------------+
# |category           |input                                                                     |
# +-------------------+--------------------------------------------------------------------------+
# |null               |what is the overhead cost associated with ioc containers like structuremap|
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''     |
# |[java]             |unix socket implementation for java                                       |
# |null               |how do you design a functional program                                    |
# |null               |in mvc when do you use and                                                |
# |null               |generating absolute urls from seam emails                                 |
# |[c++]              |initializing a static std map in c++                                      |
# |[java]             |should i provide a deep clone when implementing icloneable                |
# |null               |what s the term for design ala `` object method1 method2 method3 ``       |
# |null               |i ve never encountered a well written business layer any advice           |
# +-------------------+--------------------------------------------------------------------------+
# only showing top 10 rows
# +-----------------------------+--------------------------------------------------------------------------------+
# |category                     |input                                                                           |
# +-----------------------------+--------------------------------------------------------------------------------+
# |null                         |what is the best way to implement a singleton pattern class in actionscript 3   |
# |[.net]                       |how does one add a custom build step to an automake based project in kdevelop   |
# |[c++]                        |can not execute program if using boost c++ libraries in debug version on winxp  |
# |[sql-server-2005, sql, mysql]|database schema design                                                          |
# |[c#, c]                      |is there an alternative for sleep in c                                          |
# |[java]                       |when using ant how can i define a task only if i have some specific java version|
# |[php]                        |a delphi/freepascal lib or function that emulates the php s function parse_url  |
# |null                         |subsonic subsonic sqlquery & dates                                              |
# |[c#]                         |how can i make a button like digg it for my website                             |
# |[python]                     |accessing python egg s own metadata                                             |
# +-----------------------------+--------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------------+------------------------------------------------------------------------------------------+
# |category                 |input                                                                                     |
# +-------------------------+------------------------------------------------------------------------------------------+
# |[c++]                    |how to check if file is ascii or binary in c++                                            |
# |null                     |what is the best way to implement a singleton pattern class in actionscript 3             |
# |null                     |how do i add custom column to existing wss list template                                  |
# |[php]                    |how can i send an array to php through ajax                                               |
# |null                     |mssqlserver 2008 in virtual pc                                                            |
# |[c#, c++]                |how do i find the type of the object instance of the caller of the current function       |
# |[c#, .net]               |how can i programmatically determine if my workstation is locked                          |
# |[javascript]             |what is the best way to determine the number of days in a month with javascript           |
# |[.net, c#, visual-studio]|c # net 3 0/3 5 features in 2 0 using visual studio 2008                                  |
# |[java]                   |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client|
# +-------------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+--------------------------------------------------------------------------------------+
# |category           |input                                                                                 |
# +-------------------+--------------------------------------------------------------------------------------+
# |[c++]              |how to check if file is ascii or binary in c++                                        |
# |[java]             |saving java object graphs as xml file                                                 |
# |[.net, c#, asp.net]|sending email in net through gmail                                                    |
# |[java]             |how to do unit testing with uncertainties                                             |
# |[c#]               |how to get the device name in c #                                                     |
# |[sql-server, sql]  |sql server profiler how to filter trace to only display events from one database      |
# |null               |is there an idiomatic way to listen for changes to the dom using the prototype library|
# |[c++]              |c++ reading from a file blocks any further writing why                                |
# |[.net, c#]         |custom properties in xaml of system windows window                                    |
# |[python]           |need help variable creation in python continuation                                    |
# +-------------------+--------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +---------------------+--------------------------------------------------------------------------------+
# |category             |input                                                                           |
# +---------------------+--------------------------------------------------------------------------------+
# |[c++]                |how to check if file is ascii or binary in c++                                  |
# |null                 |clean document roles in a doc library                                           |
# |[javascript, php]    |passing a value from php to javascript                                          |
# |[sql-server, sql]    |custom aggregate functions in ms sql server                                     |
# |[visual-studio, .net]|how to get t4 files to build in visual studio                                   |
# |[java, c#]           |two phase commit/shared transaction                                             |
# |[sql-server, sql]    |sql server profiler how to filter trace to only display events from one database|
# |null                 |what are some excellent examples of user sign up forms on the web               |
# |[java]               |how do i sum a list < > of arrays                                               |
# |[eclipse]            |java date format incompatible with xquery xs date format how to fix             |
# +---------------------+--------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +---------------+---------------------------------------------------------------------------------------------+
# |category       |input                                                                                        |
# +---------------+---------------------------------------------------------------------------------------------+
# |[c#, .net]     |is there a fast way to transfer all the variables of one identical object into another in c #|
# |null           |pexpect running ssh copy id is hanging when trying to spawn a second process                 |
# |[c#, c++]      |how do i find the type of the object instance of the caller of the current function          |
# |null           |clean document roles in a doc library                                                        |
# |[java]         |how to do unit testing with uncertainties                                                    |
# |null           |google map overlay icon disappears at certain zoom level                                     |
# |[.net, asp.net]|vb net importing classes                                                                     |
# |[.net]         |is it possible to set code behind a resource dictionary in wpf for event handling            |
# |null           |how new programming frameworks help analysts designers and programmers better work together  |
# |[java]         |using noweb on a large java project                                                          |
# +---------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-------------------+------------------------------------------------------------------------------------------+
# |category           |input                                                                                     |
# +-------------------+------------------------------------------------------------------------------------------+
# |[.net, c#, asp.net]|any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''                     |
# |null               |how can i show scrollbars on a system windows forms textbox only when the text doesn t fit|
# |null               |async method call                                                                         |
# |[.net, c#, asp.net]|sending email in net through gmail                                                        |
# |[java]             |where did all the java applets go                                                         |
# |null               |in mvc when do you use and                                                                |
# |[javascript]       |actionscript3 to javascript communication best practices                                  |
# |[sql, sql-server]  |select from same table as an insert or update                                             |
# |[c++]              |c++ reading from a file blocks any further writing why                                    |
# |[asp.net]          |buttons in gridview control                                                               |
# +-------------------+------------------------------------------------------------------------------------------+
# only showing top 10 rows
# +----------------------+----------------------------------------------------------------------------------------+
# |category              |input                                                                                   |
# +----------------------+----------------------------------------------------------------------------------------+
# |[c++]                 |how to check if file is ascii or binary in c++                                          |
# |null                  |clean document roles in a doc library                                                   |
# |null                  |perform token replacements using vs post build event command                            |
# |[python]              |need help variable creation in python continuation                                      |
# |[asp.net, asp.net-mvc]|classic asp intranet and new asp net applications                                       |
# |null                  |release configuration management                                                        |
# |null                  |mac iwork/pages automation                                                              |
# |[c#]                  |c # generic sorted container that can return the sorted position of a newly added object|
# |[python]              |how can i get a list of available wireless networks on linux                            |
# |null                  |how can i add a big flash banner to the top of my wordpress blog                        |
# +----------------------+----------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +--------------------+---------------------------------------------------------------------------------------------+
# |category            |input                                                                                        |
# +--------------------+---------------------------------------------------------------------------------------------+
# |[.net, c#, asp.net] |any tool that can upgrade net 1 1 winform code to net 2 0 `` style ''                        |
# |[c#, .net]          |is there a fast way to transfer all the variables of one identical object into another in c #|
# |null                |game programming and event handlers                                                          |
# |null                |regex to match against something that is not a specific substring                            |
# |[javascript, jquery]|most efficient way to close a load page using the x sign in jquery                           |
# |[javascript, php]   |passing a value from php to javascript                                                       |
# |[java]              |where did all the java applets go                                                            |
# |[python]            |what fields should be indexed on a given table                                               |
# |null                |in mvc when do you use and                                                                   |
# |[.net, c#]          |expose a specific net object as json                                                         |
# +--------------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# +-----------------+---------------------------------------------------------------------------------------------+
# |category         |input                                                                                        |
# +-----------------+---------------------------------------------------------------------------------------------+
# |[sql-server, sql]|how do i set a sql server script s timeout from within the script                            |
# |[c#, .net]       |is there a fast way to transfer all the variables of one identical object into another in c #|
# |[c#, asp.net]    |sensitive data in viewstate                                                                  |
# |null             |center a block of content when you don t know its width in advance                           |
# |[c++]            |why does the bitconverter return bytes and how can i get the bits then                       |
# |[c++]            |can not execute program if using boost c++ libraries in debug version on winxp               |
# |[java]           |when using ant how can i define a task only if i have some specific java version             |
# |[php]            |build tar file from directory in php without exec/passthru                                   |
# |[java]           |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client   |
# |[.net, c#]       |expose a specific net object as json                                                         |
# +-----------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows
#
# 249 ms ± 18.3 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df_output.rdd.getNumPartitions()
# Out:
# 20
