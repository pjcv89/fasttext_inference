# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from classifier import predict_serie, make_pandas_udf
import pandas as pd

# %%
spark = SparkSession.builder.appName('mysession').getOrCreate()
spark.conf.set("spark.sql.execution.arrow.enabled", "true")

# %% [markdown]
# ## Build Spark DataFrame

# %%
df_input = spark.read.parquet('data/input.parquet')

# %% [markdown]
# ### Take Pandas Sample

# %%
pdf_sample = df_input.sample(False,fraction=0.10,seed=12345).toPandas()
pdf_sample.head(5)
# Out:
#                                                input
# 0                   is filestream lazy loaded in net
# 1  programmatically launching standalone adobe fl...
# 2                       encoding problem classic asp
# 3  c # winforms datagridview/sql compact negative...
# 4  suspending and notifying threads when there is...

# %% [markdown]
# ### Test `predict_serie`  function

# %% [markdown]
# **Single prediction, native vectorized inference**

# %%
predict_serie(pdf_sample.input,False,False).head(5).to_frame()
# Out:
#          0
# 0     .net
# 1     None
# 2  asp.net
# 3       c#
# 4     java

# %% [markdown]
# **Multiple prediction, native vectorized inference**

# %%
predict_serie(pdf_sample.input,True,False).head(5).to_frame()
# Out:
#                         0
# 0     [.net, c#, asp.net]
# 1                    None
# 2  [asp.net, asp.net-mvc]
# 3              [c#, .net]
# 4              [java, c#]

# %% [markdown]
# **Single prediction, rowwise inference**

# %%
predict_serie(pdf_sample.input,False,True).head(5).to_frame()
# Out:
#      input
# 0     .net
# 1     None
# 2  asp.net
# 3       c#
# 4     java

# %% [markdown]
# **Multiple prediction, rowwise inference**

# %%
predict_serie(pdf_sample.input,True,True).head(5).to_frame()
# Out:
#                     input
# 0     [.net, c#, asp.net]
# 1                    None
# 2  [asp.net, asp.net-mvc]
# 3              [c#, .net]
# 4              [java, c#]

# %% [markdown]
# **Performance comparison: Native vectorized vs. Rowwise**

# %%
# %timeit -n 20 predict_serie(pdf_sample.input,True,False)
# Out:
# 1.73 ms ± 151 µs per loop (mean ± std. dev. of 7 runs, 20 loops each)

# %%
# %timeit -n 20 predict_serie(pdf_sample.input,True,True)
# Out:
# 2.19 ms ± 102 µs per loop (mean ± std. dev. of 7 runs, 20 loops each)

# %% [markdown]
# # Approach 2.1: Pandas UDFs with (native) vectorized inference

# %% [markdown]
# ## Single prediction

# %%
udf_predict = make_pandas_udf(multi_prediction=False,rowwise=False)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------------------------------------------------------------------------+--------+
# |input                                                                       |category|
# +----------------------------------------------------------------------------+--------+
# |is filestream lazy loaded in net                                            |.net    |
# |programmatically launching standalone adobe flashplayer on linux/x11        |null    |
# |encoding problem classic asp                                                |asp.net |
# |c # winforms datagridview/sql compact negative integer in primary key column|c#      |
# |suspending and notifying threads when there is work to do                   |java    |
# |creating my own iterators                                                   |c#      |
# |css `` see through '' background crazy navigation menu problem              |asp.net |
# |sending email in net through gmail                                          |.net    |
# |specify ordinals of c++ exported functions in a dll                         |c++     |
# |in c # or any language what is/are your favourite way of removing repetition|c#      |
# +----------------------------------------------------------------------------+--------+
# only showing top 10 rows

# %% [markdown]
# ## Multiple prediction

# %%
udf_predict = make_pandas_udf(multi_prediction=True,rowwise=False)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------------------------------------------------------------------------+----------------------+
# |input                                                                       |category              |
# +----------------------------------------------------------------------------+----------------------+
# |is filestream lazy loaded in net                                            |[.net, c#, asp.net]   |
# |programmatically launching standalone adobe flashplayer on linux/x11        |null                  |
# |encoding problem classic asp                                                |[asp.net, asp.net-mvc]|
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]            |
# |suspending and notifying threads when there is work to do                   |[java, c#]            |
# |creating my own iterators                                                   |[c#, .net]            |
# |css `` see through '' background crazy navigation menu problem              |[asp.net]             |
# |sending email in net through gmail                                          |[.net, c#, asp.net]   |
# |specify ordinals of c++ exported functions in a dll                         |[c++]                 |
# |in c # or any language what is/are your favourite way of removing repetition|[c#]                  |
# +----------------------------------------------------------------------------+----------------------+
# only showing top 10 rows

# %% [markdown]
# # Approach 2.2: Pandas UDFs with rowwise inference (using Pandas' `apply` method)

# %% [markdown]
# ## Single prediction

# %%
udf_predict = make_pandas_udf(multi_prediction=False,rowwise=True)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------------------------------------------------------------------------+--------+
# |input                                                                       |category|
# +----------------------------------------------------------------------------+--------+
# |is filestream lazy loaded in net                                            |.net    |
# |programmatically launching standalone adobe flashplayer on linux/x11        |null    |
# |encoding problem classic asp                                                |asp.net |
# |c # winforms datagridview/sql compact negative integer in primary key column|c#      |
# |suspending and notifying threads when there is work to do                   |java    |
# |creating my own iterators                                                   |c#      |
# |css `` see through '' background crazy navigation menu problem              |asp.net |
# |sending email in net through gmail                                          |.net    |
# |specify ordinals of c++ exported functions in a dll                         |c++     |
# |in c # or any language what is/are your favourite way of removing repetition|c#      |
# +----------------------------------------------------------------------------+--------+
# only showing top 10 rows

# %% [markdown]
# ## Multiple prediction

# %%
udf_predict = make_pandas_udf(multi_prediction=True,rowwise=True)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +----------------------------------------------------------------------------+----------------------+
# |input                                                                       |category              |
# +----------------------------------------------------------------------------+----------------------+
# |is filestream lazy loaded in net                                            |[.net, c#, asp.net]   |
# |programmatically launching standalone adobe flashplayer on linux/x11        |null                  |
# |encoding problem classic asp                                                |[asp.net, asp.net-mvc]|
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]            |
# |suspending and notifying threads when there is work to do                   |[java, c#]            |
# |creating my own iterators                                                   |[c#, .net]            |
# |css `` see through '' background crazy navigation menu problem              |[asp.net]             |
# |sending email in net through gmail                                          |[.net, c#, asp.net]   |
# |specify ordinals of c++ exported functions in a dll                         |[c++]                 |
# |in c # or any language what is/are your favourite way of removing repetition|[c#]                  |
# +----------------------------------------------------------------------------+----------------------+
# only showing top 10 rows

# %% [markdown]
# # Performance comparison: Native vectorized vs. Rowwise

# %%
# %%timeit -n 10 
udf_predict = make_pandas_udf(multi_prediction=True,rowwise=False)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10).show(10,False)
# Out:
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# |input                                                                                                   |category                          |
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# |how to consume json web services from a windows client                                                  |[.net]                            |
# |whats the best way to start using mylyn                                                                 |[c#, .net]                        |
# |how to pass an unpersisted modified object from view back to controller without a form                  |null                              |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]                 |
# |sql query count with 0 count                                                                            |[sql, sql-server, sql-server-2005]|
# |programmatically launching standalone adobe flashplayer on linux/x11                                    |null                              |
# |how to implement a singleton in c #                                                                     |[c#]                              |
# |how can i get a list of available wireless networks on linux                                            |[python]                          |
# |c # in linux environment                                                                                |[c#]                              |
# |should i provide a deep clone when implementing icloneable                                              |[java]                            |
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------+--------------------------+
# |input                                                                                         |category                  |
# +----------------------------------------------------------------------------------------------+--------------------------+
# |making an image greyscale with gd library                                                     |null                      |
# |how can i change html attribute names with jquery                                             |[jquery, javascript, html]|
# |how do you manage infragistics webgrid data from javascript/ajax code                         |[c#]                      |
# |why learn perl python ruby if the company is using c++ c # or java as the application language|[c++, c, python]          |
# |encoding problem classic asp                                                                  |[asp.net, asp.net-mvc]    |
# |what design pattern to use for user authentication in java                                    |[java]                    |
# |image archive vs image strip                                                                  |[css]                     |
# |what s the term for design ala `` object method1 method2 method3 ``                           |null                      |
# |can you set or where is the local document root                                               |[c#]                      |
# |sql delete suspended in activity monitor                                                      |[sql, sql-server]         |
# +----------------------------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                         |category              |
# +----------------------------------------------------------------------------------------------+----------------------+
# |transforming selected text with a hotkey                                                      |null                  |
# |c the definitive truth about rand random and arc4random                                       |[c, c#]               |
# |how do you manage infragistics webgrid data from javascript/ajax code                         |[c#]                  |
# |should i have one class for every database i use                                              |[java]                |
# |building flex projects in ant/nant                                                            |[flex]                |
# |why learn perl python ruby if the company is using c++ c # or java as the application language|[c++, c, python]      |
# |converting svg to png using c #                                                               |[c#]                  |
# |encoding problem classic asp                                                                  |[asp.net, asp.net-mvc]|
# |is there a way to asynchronously filter an ilist                                              |null                  |
# |class methods as event handlers in javascript                                                 |[javascript]          |
# +----------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------------------------------------------------------------+--------------------------+
# |input                                                                                                                      |category                  |
# +---------------------------------------------------------------------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery                                                                          |[jquery, javascript, html]|
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation                   |[sql-server, sql]         |
# |daemon threads explanation                                                                                                 |null                      |
# |how do i extract the version and path from an svn working copy into a nant variable                                        |null                      |
# |creating my own iterators                                                                                                  |[c#, .net]                |
# |is it true that the smallest memory allocation in net is a byte                                                            |[.net, c#]                |
# |what is the simplest way to find the difference between 2 times in python                                                  |[python]                  |
# |anybody know why sql server 2005 throws `` sqloledb failed with no error message available result code e_fail 0x80004005 ``|[sql-server, sql]         |
# |unicode vs str decode for a utf8 encoded byte string python 2 x                                                            |[python]                  |
# |sorting and grouping nested lists in python                                                                                |[python]                  |
# +---------------------------------------------------------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------+-----------------+
# |input                                                                |category         |
# +---------------------------------------------------------------------+-----------------+
# |how do you manage infragistics webgrid data from javascript/ajax code|[c#]             |
# |how to consume json web services from a windows client               |[.net]           |
# |how does traceroute work                                             |[c#, .net]       |
# |carbide / symbian c++ change application icon                        |[c++]            |
# |building flex projects in ant/nant                                   |[flex]           |
# |is there a way to asynchronously filter an ilist                     |null             |
# |how can i determine the ip of my router/gateway in java              |[java]           |
# |class methods as event handlers in javascript                        |[javascript]     |
# |parsing t sql to parameterize a query                                |[sql, sql-server]|
# |specify ordinals of c++ exported functions in a dll                  |[c++]            |
# +---------------------------------------------------------------------+-----------------+
# only showing top 10 rows
# +----------------------------------------------------------------------------+---------------------+
# |input                                                                       |category             |
# +----------------------------------------------------------------------------+---------------------+
# |making an image greyscale with gd library                                   |null                 |
# |whats the best way to start using mylyn                                     |[c#, .net]           |
# |carbide / symbian c++ change application icon                               |[c++]                |
# |how to return a page of results from sql                                    |[sql-server, c#, sql]|
# |is it possible to define in a dependent dll s application config            |[c#, .net]           |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]           |
# |eclipse hide paths in the `` open resource '' dialog                        |null                 |
# |daemon threads explanation                                                  |null                 |
# |can you use an alias in the where clause in mysql                           |[mysql]              |
# |class methods as event handlers in javascript                               |[javascript]         |
# +----------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+--------------------------+
# |input                                                                                                   |category                  |
# +--------------------------------------------------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery                                                       |[jquery, javascript, html]|
# |vector shape on stage appears over dynamic textfield                                                    |null                      |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]         |
# |doctype rss & html entities                                                                             |[html, asp.net, css]      |
# |implementing and enforcing coding standards                                                             |[c++]                     |
# |db side encryption via nhibernate                                                                       |null                      |
# |best way to use a db table as a message/job queue                                                       |[java]                    |
# |ant and the available task what if something is not available                                           |[java]                    |
# |sending email in net through gmail                                                                      |[.net, c#, asp.net]       |
# |sql delete suspended in activity monitor                                                                |[sql, sql-server]         |
# +--------------------------------------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------------------+------------+
# |input                                                                          |category    |
# +-------------------------------------------------------------------------------+------------+
# |prevent long word to add horizontal scroll to html view                        |[asp.net]   |
# |are incrementers / decrementers var++ var etc thread safe                      |[c++]       |
# |how to implement a singleton in c #                                            |[c#]        |
# |daemon threads explanation                                                     |null        |
# |what is the best way to determine the number of days in a month with javascript|[javascript]|
# |how do i focus a foreign window                                                |null        |
# |what s the term for design ala `` object method1 method2 method3 ``            |null        |
# |stopping msi from launching an exe in the system context                       |[.net, c#]  |
# |how can i ban a whole company from my web site                                 |null        |
# |sorting and grouping nested lists in python                                    |[python]    |
# +-------------------------------------------------------------------------------+------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+-----------------+
# |input                                                                       |category         |
# +----------------------------------------------------------------------------+-----------------+
# |how can i send an array to php through ajax                                 |[php]            |
# |gantt chart controls on windows forms                                       |[windows, .net]  |
# |how does traceroute work                                                    |[c#, .net]       |
# |the necessity of hiding the salt for a hash                                 |[c++]            |
# |programmatically launching standalone adobe flashplayer on linux/x11        |null             |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]       |
# |what design pattern to use for user authentication in java                  |[java]           |
# |casting array of objects which implement interface ifoo to ifoo in c #      |[c#, c]          |
# |actionscript3 to javascript communication best practices                    |[javascript]     |
# |sql delete suspended in activity monitor                                    |[sql, sql-server]|
# +----------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +----------------------------------------------------------+----------------------+
# |input                                                     |category              |
# +----------------------------------------------------------+----------------------+
# |build tar file from directory in php without exec/passthru|[php]                 |
# |game programming and event handlers                       |null                  |
# |are incrementers / decrementers var++ var etc thread safe |[c++]                 |
# |db side encryption via nhibernate                         |null                  |
# |how to generate unit test code for methods                |[java, c#]            |
# |encoding problem classic asp                              |[asp.net, asp.net-mvc]|
# |how do i call net code c # /vb net from vbscript          |[c#, .net]            |
# |can you use an alias in the where clause in mysql         |[mysql]               |
# |creating my own iterators                                 |[c#, .net]            |
# |should i provide a deep clone when implementing icloneable|[java]                |
# +----------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+----------------------+
# |input                                                                       |category              |
# +----------------------------------------------------------------------------+----------------------+
# |should i have one class for every database i use                            |[java]                |
# |carbide / symbian c++ change application icon                               |[c++]                 |
# |best update method for mysql db                                             |[mysql, sql, database]|
# |how do you quickly find the url for a win32 api on msdn                     |null                  |
# |eclipse hide paths in the `` open resource '' dialog                        |null                  |
# |how would you attack this polymorphism string building problem              |[c#]                  |
# |stopping msi from launching an exe in the system context                    |[.net, c#]            |
# |drawing a custom label on a pie chart in yahoo s flash library astra        |null                  |
# |in c # or any language what is/are your favourite way of removing repetition|[c#]                  |
# |how do you maintain large t sql procedures                                  |[sql, sql-server]     |
# +----------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
# +---------------------------------------------------------------------+----------------------------------+
# |input                                                                |category                          |
# +---------------------------------------------------------------------+----------------------------------+
# |making an image greyscale with gd library                            |null                              |
# |how do you manage infragistics webgrid data from javascript/ajax code|[c#]                              |
# |how to consume json web services from a windows client               |[.net]                            |
# |prevent long word to add horizontal scroll to html view              |[asp.net]                         |
# |sql query count with 0 count                                         |[sql, sql-server, sql-server-2005]|
# |encoding problem classic asp                                         |[asp.net, asp.net-mvc]            |
# |what is the best way to see what files are locked in subversion      |null                              |
# |is there a way to asynchronously filter an ilist                     |null                              |
# |ant and the available task what if something is not available        |[java]                            |
# |how can i determine the ip of my router/gateway in java              |[java]                            |
# +---------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------+---------------------+
# |input                                                        |category             |
# +-------------------------------------------------------------+---------------------+
# |making an image greyscale with gd library                    |null                 |
# |build tar file from directory in php without exec/passthru   |[php]                |
# |game programming and event handlers                          |null                 |
# |how to disable visual studio macro `` tip '' balloon         |[visual-studio]      |
# |the necessity of hiding the salt for a hash                  |[c++]                |
# |how to return a page of results from sql                     |[sql-server, c#, sql]|
# |is there a way to asynchronously filter an ilist             |null                 |
# |vertical text with jquery                                    |[jquery, javascript] |
# |stopping msi from launching an exe in the system context     |[.net, c#]           |
# |how to serialize an object to xml without getting xmlns `` ``|[c#]                 |
# +-------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+----------------------+
# |input                                                                 |category              |
# +----------------------------------------------------------------------+----------------------+
# |getting odd error on net executenonquery                              |[.net, c#]            |
# |carbide / symbian c++ change application icon                         |[c++]                 |
# |encoding problem classic asp                                          |[asp.net, asp.net-mvc]|
# |best way to use a db table as a message/job queue                     |[java]                |
# |how can i determine the ip of my router/gateway in java               |[java]                |
# |image archive vs image strip                                          |[css]                 |
# |can you set or where is the local document root                       |[c#]                  |
# |casting array of objects which implement interface ifoo to ifoo in c #|[c#, c]               |
# |how can i ban a whole company from my web site                        |null                  |
# |determine if type is a pointer in a template function                 |[c++]                 |
# +----------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------+----------+
# |input                                                                |category  |
# +---------------------------------------------------------------------+----------+
# |how do you manage infragistics webgrid data from javascript/ajax code|[c#]      |
# |how to effectively implement sessions in gae                         |null      |
# |game programming and event handlers                                  |null      |
# |how does traceroute work                                             |[c#, .net]|
# |carbide / symbian c++ change application icon                        |[c++]     |
# |implementing and enforcing coding standards                          |[c++]     |
# |how do i focus a foreign window                                      |null      |
# |how do i calculate the previous business day in ksh shell script     |null      |
# |rendered pixel width data for each character in a browser s font     |null      |
# |decoding chunked http with actionscript                              |null      |
# +---------------------------------------------------------------------+----------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+--------------------+
# |input                                                                                                   |category            |
# +--------------------------------------------------------------------------------------------------------+--------------------+
# |prevent long word to add horizontal scroll to html view                                                 |[asp.net]           |
# |how do you deal with connection strings when deploying an asp net site                                  |[asp.net]           |
# |how do i add custom column to existing wss list template                                                |null                |
# |game programming and event handlers                                                                     |null                |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]   |
# |how to generate unit test code for methods                                                              |[java, c#]          |
# |how do i call net code c # /vb net from vbscript                                                        |[c#, .net]          |
# |is there a way to asynchronously filter an ilist                                                        |null                |
# |can you use an alias in the where clause in mysql                                                       |[mysql]             |
# |vertical text with jquery                                                                               |[jquery, javascript]|
# +--------------------------------------------------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------------+-----------------+
# |input                                                                    |category         |
# +-------------------------------------------------------------------------+-----------------+
# |sql server and the guest account what is this for                        |[sql-server, sql]|
# |how do i add custom column to existing wss list template                 |null             |
# |getting odd error on net executenonquery                                 |[.net, c#]       |
# |can you use an alias in the where clause in mysql                        |[mysql]          |
# |what design pattern to use for user authentication in java               |[java]           |
# |what s the term for design ala `` object method1 method2 method3 ``      |null             |
# |numbering regex submatches                                               |[php]            |
# |specify ordinals of c++ exported functions in a dll                      |[c++]            |
# |what is the simplest way to find the difference between 2 times in python|[python]         |
# |using lists in c #                                                       |[c#]             |
# +-------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                                           |category              |
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |should i have one class for every database i use                                                                |[java]                |
# |how to implement a singleton in c #                                                                             |[c#]                  |
# |eclipse hide paths in the `` open resource '' dialog                                                            |null                  |
# |daemon threads explanation                                                                                      |null                  |
# |which css tag creates a box like this with title                                                                |null                  |
# |casting array of objects which implement interface ifoo to ifoo in c #                                          |[c#, c]               |
# |unix socket implementation for java                                                                             |[java]                |
# |asp net users are logged out when deploying a new file to the server                                            |[asp.net]             |
# |asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|[asp.net-mvc, asp.net]|
# |patterns for the overlap of two objects                                                                         |[java, c++]           |
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------+--------------------+
# |input                                                        |category            |
# +-------------------------------------------------------------+--------------------+
# |transforming selected text with a hotkey                     |null                |
# |how does traceroute work                                     |[c#, .net]          |
# |authoritative source on xml sig                              |[.net, php, c#]     |
# |ms sql 2000 turn off logging during stored procedure         |[sql-server, sql]   |
# |doctype rss & html entities                                  |[html, asp.net, css]|
# |best way to use a db table as a message/job queue            |[java]              |
# |what is the aspnet_client folder for under the iis structure |null                |
# |daemon threads explanation                                   |null                |
# |how can i determine the ip of my router/gateway in java      |[java]              |
# |how to serialize an object to xml without getting xmlns `` ``|[c#]                |
# +-------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+-----------------+
# |input                                                                 |category         |
# +----------------------------------------------------------------------+-----------------+
# |gantt chart controls on windows forms                                 |[windows, .net]  |
# |game programming and event handlers                                   |null             |
# |while clause in t sql that loops forever                              |[sql, sql-server]|
# |casting array of objects which implement interface ifoo to ifoo in c #|[c#, c]          |
# |sql delete suspended in activity monitor                              |[sql, sql-server]|
# |has and belongs to many relationship with multiple databases          |null             |
# |find all storage devices attached to a linux machine                  |null             |
# |does the iphone timeout if a function takes too long to execute       |null             |
# |is there an alternative for sleep in c                                |[c#, c]          |
# |can t create a subversion repository with eclipse 3 4 0 svn 1 5 1     |[java, eclipse]  |
# +----------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------+----------------------+
# |input                                                         |category              |
# +--------------------------------------------------------------+----------------------+
# |build tar file from directory in php without exec/passthru    |[php]                 |
# |python beyond the basics                                      |[python]              |
# |how to effectively implement sessions in gae                  |null                  |
# |best update method for mysql db                               |[mysql, sql, database]|
# |what is the aspnet_client folder for under the iis structure  |null                  |
# |how can i determine the ip of my router/gateway in java       |[java]                |
# |how do i focus a foreign window                               |null                  |
# |be notified when visual/logical child added/removed           |[c#, c++]             |
# |css `` see through '' background crazy navigation menu problem|[asp.net]             |
# |sending email in net through gmail                            |[.net, c#, asp.net]   |
# +--------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+----------------------+
# |input                                                                                 |category              |
# +--------------------------------------------------------------------------------------+----------------------+
# |sql server and the guest account what is this for                                     |[sql-server, sql]     |
# |gantt chart controls on windows forms                                                 |[windows, .net]       |
# |whats the best way to start using mylyn                                               |[c#, .net]            |
# |python beyond the basics                                                              |[python]              |
# |how to pass an unpersisted modified object from view back to controller without a form|null                  |
# |getting odd error on net executenonquery                                              |[.net, c#]            |
# |best update method for mysql db                                                       |[mysql, sql, database]|
# |while clause in t sql that loops forever                                              |[sql, sql-server]     |
# |doctype rss & html entities                                                           |[html, asp.net, css]  |
# |encoding problem classic asp                                                          |[asp.net, asp.net-mvc]|
# +--------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+--------------------+
# |input                                                                       |category            |
# +----------------------------------------------------------------------------+--------------------+
# |sql server and the guest account what is this for                           |[sql-server, sql]   |
# |how can i send an array to php through ajax                                 |[php]               |
# |game programming and event handlers                                         |null                |
# |doctype rss & html entities                                                 |[html, asp.net, css]|
# |how can i get a list of available wireless networks on linux                |[python]            |
# |how can i create prototype methods like javascript in c # net               |[c#, .net]          |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]          |
# |suspending and notifying threads when there is work to do                   |[java, c#]          |
# |how can i determine the ip of my router/gateway in java                     |[java]              |
# |should db layer members be static or instance                               |null                |
# +----------------------------------------------------------------------------+--------------------+
# only showing top 10 rows
# +--------------------------------------------------------------------------------------------------------+---------------------+
# |input                                                                                                   |category             |
# +--------------------------------------------------------------------------------------------------------+---------------------+
# |transforming selected text with a hotkey                                                                |null                 |
# |build tar file from directory in php without exec/passthru                                              |[php]                |
# |how do i add custom column to existing wss list template                                                |null                 |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]    |
# |building flex projects in ant/nant                                                                      |[flex]               |
# |authoritative source on xml sig                                                                         |[.net, php, c#]      |
# |how to implement a singleton in c #                                                                     |[c#]                 |
# |db side encryption via nhibernate                                                                       |null                 |
# |c # in linux environment                                                                                |[c#]                 |
# |what are the limits of ruby on rails                                                                    |[ruby, ruby-on-rails]|
# +--------------------------------------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------+-------------------+
# |input                                                               |category           |
# +--------------------------------------------------------------------+-------------------+
# |authoritative source on xml sig                                     |[.net, php, c#]    |
# |how can i get a list of available wireless networks on linux        |[python]           |
# |how do you quickly find the url for a win32 api on msdn             |null               |
# |ant and the available task what if something is not available       |[java]             |
# |what design pattern to use for user authentication in java          |[java]             |
# |sending email in net through gmail                                  |[.net, c#, asp.net]|
# |using lists in c #                                                  |[c#]               |
# |drawing a custom label on a pie chart in yahoo s flash library astra|null               |
# |which css tag creates a box like this with title                    |null               |
# |thotkey with win key support                                        |[c#]               |
# +--------------------------------------------------------------------+-------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+----------------------+
# |input                                                                 |category              |
# +----------------------------------------------------------------------+----------------------+
# |sql server and the guest account what is this for                     |[sql-server, sql]     |
# |python beyond the basics                                              |[python]              |
# |how do you deal with connection strings when deploying an asp net site|[asp.net]             |
# |getting odd error on net executenonquery                              |[.net, c#]            |
# |how can i get a list of available wireless networks on linux          |[python]              |
# |how do you quickly find the url for a win32 api on msdn               |null                  |
# |encoding problem classic asp                                          |[asp.net, asp.net-mvc]|
# |can you use an alias in the where clause in mysql                     |[mysql]               |
# |what s the term for design ala `` object method1 method2 method3 ``   |null                  |
# |should db layer members be static or instance                         |null                  |
# +----------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                                   |category              |
# +--------------------------------------------------------------------------------------------------------+----------------------+
# |how can i send an array to php through ajax                                                             |[php]                 |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]     |
# |how to generate unit test code for methods                                                              |[java, c#]            |
# |encoding problem classic asp                                                                            |[asp.net, asp.net-mvc]|
# |should db layer members be static or instance                                                           |null                  |
# |how to serialize an object to xml without getting xmlns `` ``                                           |[c#]                  |
# |why is visual studio constantly crashing                                                                |[visual-studio]       |
# |what techniques can you use to profile your code                                                        |[c#]                  |
# |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client              |[java]                |
# |can t create a subversion repository with eclipse 3 4 0 svn 1 5 1                                       |[java, eclipse]       |
# +--------------------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+---------------------+
# |input                                                                                 |category             |
# +--------------------------------------------------------------------------------------+---------------------+
# |transforming selected text with a hotkey                                              |null                 |
# |whats the best way to start using mylyn                                               |[c#, .net]           |
# |doctype rss & html entities                                                           |[html, asp.net, css] |
# |how can i determine the ip of my router/gateway in java                               |[java]               |
# |should i provide a deep clone when implementing icloneable                            |[java]               |
# |stopping msi from launching an exe in the system context                              |[.net, c#]           |
# |what are the limits of ruby on rails                                                  |[ruby, ruby-on-rails]|
# |why is visual studio constantly crashing                                              |[visual-studio]      |
# |how can i convert my current page to pdf after some content dynamically added via ajax|[c#]                 |
# |sorting and grouping nested lists in python                                           |[python]             |
# +--------------------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------+----------------+
# |input                                                                                         |category        |
# +----------------------------------------------------------------------------------------------+----------------+
# |how can i send an array to php through ajax                                                   |[php]           |
# |why learn perl python ruby if the company is using c++ c # or java as the application language|[c++, c, python]|
# |how do you quickly find the url for a win32 api on msdn                                       |null            |
# |what is the aspnet_client folder for under the iis structure                                  |null            |
# |what is the best way to see what files are locked in subversion                               |null            |
# |percentages of subtotal in a report                                                           |[c++, java]     |
# |what is the best way to determine the number of days in a month with javascript               |[javascript]    |
# |be notified when visual/logical child added/removed                                           |[c#, c++]       |
# |stopping msi from launching an exe in the system context                                      |[.net, c#]      |
# |which css tag creates a box like this with title                                              |null            |
# +----------------------------------------------------------------------------------------------+----------------+
# only showing top 10 rows
# +--------------------------------------------------------------------------------------------------------+-------------------+
# |input                                                                                                   |category           |
# +--------------------------------------------------------------------------------------------------------+-------------------+
# |is filestream lazy loaded in net                                                                        |[.net, c#, asp.net]|
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]  |
# |why learn perl python ruby if the company is using c++ c # or java as the application language          |[c++, c, python]   |
# |percentages of subtotal in a report                                                                     |[c++, java]        |
# |authenticating against active directory with java on linux                                              |[java]             |
# |asp net users are logged out when deploying a new file to the server                                    |[asp.net]          |
# |unicode vs str decode for a utf8 encoded byte string python 2 x                                         |[python]           |
# |uiwebview within a scrollview does not redraw                                                           |null               |
# |what does it mean when a bug doesn t crash the program                                                  |[c++, java, c#]    |
# |what s the nicest way to do observer/observable in objective c iphone version                           |null               |
# +--------------------------------------------------------------------------------------------------------+-------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------+----------------------------------+
# |input                                                          |category                          |
# +---------------------------------------------------------------+----------------------------------+
# |building flex projects in ant/nant                             |[flex]                            |
# |sql query count with 0 count                                   |[sql, sql-server, sql-server-2005]|
# |how to implement a singleton in c #                            |[c#]                              |
# |c # in linux environment                                       |[c#]                              |
# |percentages of subtotal in a report                            |[c++, java]                       |
# |creating my own iterators                                      |[c#, .net]                        |
# |is it true that the smallest memory allocation in net is a byte|[.net, c#]                        |
# |css `` see through '' background crazy navigation menu problem |[asp.net]                         |
# |parsing t sql to parameterize a query                          |[sql, sql-server]                 |
# |using lists in c #                                             |[c#]                              |
# +---------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+----------------------+
# |input                                                                 |category              |
# +----------------------------------------------------------------------+----------------------+
# ...
# |ant and the available task what if something is not available        |[java]           |
# |image archive vs image strip                                         |[css]            |
# |parsing t sql to parameterize a query                                |[sql, sql-server]|
# |using lists in c #                                                   |[c#]             |
# |mvc preview 4 no route in the route table matches the supplied values|null             |
# +---------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +-----------------------------------------------------------------------+---------------------+
# |input                                                                  |category             |
# +-----------------------------------------------------------------------+---------------------+
# |is filestream lazy loaded in net                                       |[.net, c#, asp.net]  |
# |how do i add custom column to existing wss list template               |null                 |
# |mac iwork/pages automation                                             |null                 |
# |how do i call net code c # /vb net from vbscript                       |[c#, .net]           |
# |what is the aspnet_client folder for under the iis structure           |null                 |
# |is there a way to asynchronously filter an ilist                       |null                 |
# |how would you attack this polymorphism string building problem         |[c#]                 |
# |what are the limits of ruby on rails                                   |[ruby, ruby-on-rails]|
# |thotkey with win key support                                           |[c#]                 |
# |how to add a `` driver '' to javax comm serial port programming in java|[java]               |
# +-----------------------------------------------------------------------+---------------------+
# only showing top 10 rows
# +-------------------------------------------------------------------------------+---------------------+
# |input                                                                          |category             |
# +-------------------------------------------------------------------------------+---------------------+
# |python beyond the basics                                                       |[python]             |
# |are incrementers / decrementers var++ var etc thread safe                      |[c++]                |
# |programmatically launching standalone adobe flashplayer on linux/x11           |null                 |
# |ms sql 2000 turn off logging during stored procedure                           |[sql-server, sql]    |
# |how to return a page of results from sql                                       |[sql-server, c#, sql]|
# |is it possible to define in a dependent dll s application config               |[c#, .net]           |
# |what is the best way to determine the number of days in a month with javascript|[javascript]         |
# |setting the height of a div dynamically                                        |[c#]                 |
# |image archive vs image strip                                                   |[css]                |
# |what s the term for design ala `` object method1 method2 method3 ``            |null                 |
# +-------------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------+-----------------+
# |input                                                        |category         |
# +-------------------------------------------------------------+-----------------+
# |are incrementers / decrementers var++ var etc thread safe    |[c++]            |
# |the necessity of hiding the salt for a hash                  |[c++]            |
# |implementing and enforcing coding standards                  |[c++]            |
# |db side encryption via nhibernate                            |null             |
# |converting svg to png using c #                              |[c#]             |
# |ant and the available task what if something is not available|[java]           |
# |how to serialize an object to xml without getting xmlns `` ``|[c#]             |
# |why is visual studio constantly crashing                     |[visual-studio]  |
# |authenticating against active directory with java on linux   |[java]           |
# |sql delete suspended in activity monitor                     |[sql, sql-server]|
# +-------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------------+-----------------+
# |input                                                                    |category         |
# +-------------------------------------------------------------------------+-----------------+
# |gantt chart controls on windows forms                                    |[windows, .net]  |
# |how to consume json web services from a windows client                   |[.net]           |
# |whats the best way to start using mylyn                                  |[c#, .net]       |
# |what is the best way to see what files are locked in subversion          |null             |
# |how do i focus a foreign window                                          |null             |
# |parsing t sql to parameterize a query                                    |[sql, sql-server]|
# |how do i calculate the previous business day in ksh shell script         |null             |
# |what is the simplest way to find the difference between 2 times in python|[python]         |
# |which css tag creates a box like this with title                         |null             |
# |actionscript3 to javascript communication best practices                 |[javascript]     |
# +-------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------+--------------------------+
# |input                                                          |category                  |
# +---------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery              |[jquery, javascript, html]|
# |is filestream lazy loaded in net                               |[.net, c#, asp.net]       |
# |python beyond the basics                                       |[python]                  |
# |game programming and event handlers                            |null                      |
# |how does traceroute work                                       |[c#, .net]                |
# |ms sql 2000 turn off logging during stored procedure           |[sql-server, sql]         |
# |how can i get a list of available wireless networks on linux   |[python]                  |
# |what is the best way to see what files are locked in subversion|null                      |
# |css `` see through '' background crazy navigation menu problem |[asp.net]                 |
# |sending email in net through gmail                             |[.net, c#, asp.net]       |
# +---------------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------+----------------------+
# |input                                                                |category              |
# +---------------------------------------------------------------------+----------------------+
# |how can i send an array to php through ajax                          |[php]                 |
# |how do you manage infragistics webgrid data from javascript/ajax code|[c#]                  |
# |how do i add custom column to existing wss list template             |null                  |
# |carbide / symbian c++ change application icon                        |[c++]                 |
# |building flex projects in ant/nant                                   |[flex]                |
# |best update method for mysql db                                      |[mysql, sql, database]|
# |how do i call net code c # /vb net from vbscript                     |[c#, .net]            |
# |daemon threads explanation                                           |null                  |
# |how can i determine the ip of my router/gateway in java              |[java]                |
# |parsing t sql to parameterize a query                                |[sql, sql-server]     |
# +---------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +------------------------------------------------------------+----------+
# |input                                                       |category  |
# +------------------------------------------------------------+----------+
# |c the definitive truth about rand random and arc4random     |[c, c#]   |
# |how to consume json web services from a windows client      |[.net]    |
# |prevent long word to add horizontal scroll to html view     |[asp.net] |
# |should i have one class for every database i use            |[java]    |
# |the necessity of hiding the salt for a hash                 |[c++]     |
# |how can i get a list of available wireless networks on linux|[python]  |
# |how to generate unit test code for methods                  |[java, c#]|
# |can you use an alias in the where clause in mysql           |[mysql]   |
# |how can i determine the ip of my router/gateway in java     |[java]    |
# |image archive vs image strip                                |[css]     |
# +------------------------------------------------------------+----------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+---------------------+
# |input                                                                 |category             |
# +----------------------------------------------------------------------+---------------------+
# |transforming selected text with a hotkey                              |null                 |
# |build tar file from directory in php without exec/passthru            |[php]                |
# |is filestream lazy loaded in net                                      |[.net, c#, asp.net]  |
# |getting odd error on net executenonquery                              |[.net, c#]           |
# |what design pattern to use for user authentication in java            |[java]               |
# |what are the limits of ruby on rails                                  |[ruby, ruby-on-rails]|
# |casting array of objects which implement interface ifoo to ifoo in c #|[c#, c]              |
# |thotkey with win key support                                          |[c#]                 |
# |sql delete suspended in activity monitor                              |[sql, sql-server]    |
# |html over flash without stopping interaction with flash               |null                 |
# +----------------------------------------------------------------------+---------------------+
# only showing top 10 rows
# +------------------------------------------------------------------------+--------------------+
# |input                                                                   |category            |
# +------------------------------------------------------------------------+--------------------+
# |making an image greyscale with gd library                               |null                |
# |transforming selected text with a hotkey                                |null                |
# |build tar file from directory in php without exec/passthru              |[php]               |
# |python beyond the basics                                                |[python]            |
# |doctype rss & html entities                                             |[html, asp.net, css]|
# |how to generate unit test code for methods                              |[java, c#]          |
# |what is the best way to see what files are locked in subversion         |null                |
# |creating my own iterators                                               |[c#, .net]          |
# |can you set or where is the local document root                         |[c#]                |
# |why is app_offline failing to work as soon as you it starts loading dlls|[.net, c#]          |
# +------------------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------+--------+
# |input                                                         |category|
# +--------------------------------------------------------------+--------+
# |how can i send an array to php through ajax                   |[php]   |
# |c the definitive truth about rand random and arc4random       |[c, c#] |
# |how to consume json web services from a windows client        |[.net]  |
# |carbide / symbian c++ change application icon                 |[c++]   |
# |what design pattern to use for user authentication in java    |[java]  |
# |how would you attack this polymorphism string building problem|[c#]    |
# |should i provide a deep clone when implementing icloneable    |[java]  |
# |specify ordinals of c++ exported functions in a dll           |[c++]   |
# |unix socket implementation for java                           |[java]  |
# |design patterns architecture astronaut                        |null    |
# +--------------------------------------------------------------+--------+
# only showing top 10 rows
#
# +----------------------------------------------------------------+-----------------+
# |input                                                           |category         |
# +----------------------------------------------------------------+-----------------+
# |are incrementers / decrementers var++ var etc thread safe       |[c++]            |
# |how can i get a list of available wireless networks on linux    |[python]         |
# |how can i create prototype methods like javascript in c # net   |[c#, .net]       |
# |converting svg to png using c #                                 |[c#]             |
# |is it possible to define in a dependent dll s application config|[c#, .net]       |
# |be notified when visual/logical child added/removed             |[c#, c++]        |
# |numbering regex submatches                                      |[php]            |
# |parsing t sql to parameterize a query                           |[sql, sql-server]|
# |how do i calculate the previous business day in ksh shell script|null             |
# |decoding chunked http with actionscript                         |null             |
# +----------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------+-------------------+
# |input                                                           |category           |
# +----------------------------------------------------------------+-------------------+
# |transforming selected text with a hotkey                        |null               |
# |sql server and the guest account what is this for               |[sql-server, sql]  |
# |prevent long word to add horizontal scroll to html view         |[asp.net]          |
# |is filestream lazy loaded in net                                |[.net, c#, asp.net]|
# |the necessity of hiding the salt for a hash                     |[c++]              |
# |how to implement a singleton in c #                             |[c#]               |
# |creating my own iterators                                       |[c#, .net]         |
# |sending email in net through gmail                              |[.net, c#, asp.net]|
# |rendered pixel width data for each character in a browser s font|null               |
# |actionscript3 to javascript communication best practices        |[javascript]       |
# +----------------------------------------------------------------+-------------------+
# only showing top 10 rows
#
# 467 ms ± 34.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit -n 10 
udf_predict = make_pandas_udf(multi_prediction=True,rowwise=True)
df_output = df_input.withColumn("category",udf_predict(col("input")))
df_output.sample(False,.10).show(10,False)
# Out:
# +--------------------------------------------------------------------------------------+--------------------+
# |input                                                                                 |category            |
# +--------------------------------------------------------------------------------------+--------------------+
# |how to consume json web services from a windows client                                |[.net]              |
# |prevent long word to add horizontal scroll to html view                               |[asp.net]           |
# |how do you deal with connection strings when deploying an asp net site                |[asp.net]           |
# |vector shape on stage appears over dynamic textfield                                  |null                |
# |how to pass an unpersisted modified object from view back to controller without a form|null                |
# |c # in linux environment                                                              |[c#]                |
# |what is the aspnet_client folder for under the iis structure                          |null                |
# |what is the best way to see what files are locked in subversion                       |null                |
# |vertical text with jquery                                                             |[jquery, javascript]|
# |setting the height of a div dynamically                                               |[c#]                |
# +--------------------------------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +-----------------------------------------------------------------------------------+---------------+
# |input                                                                              |category       |
# +-----------------------------------------------------------------------------------+---------------+
# |gantt chart controls on windows forms                                              |[windows, .net]|
# |how to effectively implement sessions in gae                                       |null           |
# |vector shape on stage appears over dynamic textfield                               |null           |
# |how does traceroute work                                                           |[c#, .net]     |
# |best way to use a db table as a message/job queue                                  |[java]         |
# |suspending and notifying threads when there is work to do                          |[java, c#]     |
# |eclipse hide paths in the `` open resource '' dialog                               |null           |
# |what is the best way to see what files are locked in subversion                    |null           |
# |daemon threads explanation                                                         |null           |
# |how do i extract the version and path from an svn working copy into a nant variable|null           |
# +-----------------------------------------------------------------------------------+---------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+-----------------+
# |input                                                                 |category         |
# +----------------------------------------------------------------------+-----------------+
# |how do you deal with connection strings when deploying an asp net site|[asp.net]        |
# |how do i add custom column to existing wss list template              |null             |
# |vector shape on stage appears over dynamic textfield                  |null             |
# |while clause in t sql that loops forever                              |[sql, sql-server]|
# |ms sql 2000 turn off logging during stored procedure                  |[sql-server, sql]|
# |c # in linux environment                                              |[c#]             |
# |how do i call net code c # /vb net from vbscript                      |[c#, .net]       |
# |how can i determine the ip of my router/gateway in java               |[java]           |
# |class methods as event handlers in javascript                         |[javascript]     |
# |how do i calculate the previous business day in ksh shell script      |null             |
# +----------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+-------------------+
# |input                                                                       |category           |
# +----------------------------------------------------------------------------+-------------------+
# |build tar file from directory in php without exec/passthru                  |[php]              |
# |should i have one class for every database i use                            |[java]             |
# |getting odd error on net executenonquery                                    |[.net, c#]         |
# |how to implement a singleton in c #                                         |[c#]               |
# |post from one controller action to another not redirect                     |null               |
# |converting svg to png using c #                                             |[c#]               |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]         |
# |sending email in net through gmail                                          |[.net, c#, asp.net]|
# |how to serialize an object to xml without getting xmlns `` ``               |[c#]               |
# |rendered pixel width data for each character in a browser s font            |null               |
# +----------------------------------------------------------------------------+-------------------+
# only showing top 10 rows
#
# +-----------------------------------------------------------------------+---------------+
# |input                                                                  |category       |
# +-----------------------------------------------------------------------+---------------+
# |how to consume json web services from a windows client                 |[.net]         |
# |building flex projects in ant/nant                                     |[flex]         |
# |db side encryption via nhibernate                                      |null           |
# |eclipse text comparison order                                          |[eclipse, java]|
# |should i provide a deep clone when implementing icloneable             |[java]         |
# |numbering regex submatches                                             |[php]          |
# |actionscript3 to javascript communication best practices               |[javascript]   |
# |how can i ban a whole company from my web site                         |null           |
# |how to add a `` driver '' to javax comm serial port programming in java|[java]         |
# |patterns for the overlap of two objects                                |[java, c++]    |
# +-----------------------------------------------------------------------+---------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------+--------------------------+
# |input                                                           |category                  |
# +----------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery               |[jquery, javascript, html]|
# |how to implement a singleton in c #                             |[c#]                      |
# |what design pattern to use for user authentication in java      |[java]                    |
# |be notified when visual/logical child added/removed             |[c#, c++]                 |
# |stopping msi from launching an exe in the system context        |[.net, c#]                |
# |specify ordinals of c++ exported functions in a dll             |[c++]                     |
# |rendered pixel width data for each character in a browser s font|null                      |
# |what techniques can you use to profile your code                |[c#]                      |
# |patterns for the overlap of two objects                         |[java, c++]               |
# |what does it mean when a bug doesn t crash the program          |[c++, java, c#]           |
# +----------------------------------------------------------------+--------------------------+
# only showing top 10 rows
# +--------------------------------------------------------------------+---------------------+
# |input                                                               |category             |
# +--------------------------------------------------------------------+---------------------+
# |transforming selected text with a hotkey                            |null                 |
# |is filestream lazy loaded in net                                    |[.net, c#, asp.net]  |
# |programmatically launching standalone adobe flashplayer on linux/x11|null                 |
# |how to return a page of results from sql                            |[sql-server, c#, sql]|
# |c # in linux environment                                            |[c#]                 |
# |how can i create prototype methods like javascript in c # net       |[c#, .net]           |
# |suspending and notifying threads when there is work to do           |[java, c#]           |
# |can you use an alias in the where clause in mysql                   |[mysql]              |
# |sending email in net through gmail                                  |[.net, c#, asp.net]  |
# |specify ordinals of c++ exported functions in a dll                 |[c++]                |
# +--------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+---------------------+
# |input                                                                                                   |category             |
# +--------------------------------------------------------------------------------------------------------+---------------------+
# |how can i send an array to php through ajax                                                             |[php]                |
# |prevent long word to add horizontal scroll to html view                                                 |[asp.net]            |
# |how do i add custom column to existing wss list template                                                |null                 |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]    |
# |are incrementers / decrementers var++ var etc thread safe                                               |[c++]                |
# |how to disable visual studio macro `` tip '' balloon                                                    |[visual-studio]      |
# |how can i get a list of available wireless networks on linux                                            |[python]             |
# |how to return a page of results from sql                                                                |[sql-server, c#, sql]|
# |how can i create prototype methods like javascript in c # net                                           |[c#, .net]           |
# |best way to use a db table as a message/job queue                                                       |[java]               |
# +--------------------------------------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+----------+
# |input                                                                       |category  |
# +----------------------------------------------------------------------------+----------+
# |making an image greyscale with gd library                                   |null      |
# |c the definitive truth about rand random and arc4random                     |[c, c#]   |
# |build tar file from directory in php without exec/passthru                  |[php]     |
# |how do you manage infragistics webgrid data from javascript/ajax code       |[c#]      |
# |prevent long word to add horizontal scroll to html view                     |[asp.net] |
# |game programming and event handlers                                         |null      |
# |c # lambda expressions or delegates as a properties or arguments            |[c#]      |
# |db side encryption via nhibernate                                           |null      |
# |is it possible to define in a dependent dll s application config            |[c#, .net]|
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]|
# +----------------------------------------------------------------------------+----------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------+--------------------+
# |input                                                                |category            |
# +---------------------------------------------------------------------+--------------------+
# |how do you manage infragistics webgrid data from javascript/ajax code|[c#]                |
# |how do i add custom column to existing wss list template             |null                |
# |should i have one class for every database i use                     |[java]              |
# |how does traceroute work                                             |[c#, .net]          |
# |mac iwork/pages automation                                           |null                |
# |how to implement a singleton in c #                                  |[c#]                |
# |doctype rss & html entities                                          |[html, asp.net, css]|
# |how do i call net code c # /vb net from vbscript                     |[c#, .net]          |
# |what is the aspnet_client folder for under the iis structure         |null                |
# |css `` see through '' background crazy navigation menu problem       |[asp.net]           |
# +---------------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+----------------------------------+
# |input                                                                 |category                          |
# +----------------------------------------------------------------------+----------------------------------+
# |making an image greyscale with gd library                             |null                              |
# |how can i change html attribute names with jquery                     |[jquery, javascript, html]        |
# |whats the best way to start using mylyn                               |[c#, .net]                        |
# |how do you deal with connection strings when deploying an asp net site|[asp.net]                         |
# |game programming and event handlers                                   |null                              |
# |sql query count with 0 count                                          |[sql, sql-server, sql-server-2005]|
# |how to implement a singleton in c #                                   |[c#]                              |
# |encoding problem classic asp                                          |[asp.net, asp.net-mvc]            |
# |what design pattern to use for user authentication in java            |[java]                            |
# |be notified when visual/logical child added/removed                   |[c#, c++]                         |
# +----------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------------+--------------------------+
# |input                                                                    |category                  |
# +-------------------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery                        |[jquery, javascript, html]|
# |gantt chart controls on windows forms                                    |[windows, .net]           |
# |c # lambda expressions or delegates as a properties or arguments         |[c#]                      |
# |is it possible to define in a dependent dll s application config         |[c#, .net]                |
# |eclipse hide paths in the `` open resource '' dialog                     |null                      |
# |percentages of subtotal in a report                                      |[c++, java]               |
# |should i provide a deep clone when implementing icloneable               |[java]                    |
# |class methods as event handlers in javascript                            |[javascript]              |
# |what is the simplest way to find the difference between 2 times in python|[python]                  |
# |can you set or where is the local document root                          |[c#]                      |
# +-------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
# +---------------------------------------------------------------------------------------------------------------------------+-----------------+
# |input                                                                                                                      |category         |
# +---------------------------------------------------------------------------------------------------------------------------+-----------------+
# |authoritative source on xml sig                                                                                            |[.net, php, c#]  |
# |programmatically launching standalone adobe flashplayer on linux/x11                                                       |null             |
# |converting svg to png using c #                                                                                            |[c#]             |
# |is there a way to asynchronously filter an ilist                                                                           |null             |
# |sql delete suspended in activity monitor                                                                                   |[sql, sql-server]|
# |anybody know why sql server 2005 throws `` sqloledb failed with no error message available result code e_fail 0x80004005 ``|[sql-server, sql]|
# |how do you maintain large t sql procedures                                                                                 |[sql, sql-server]|
# |unicode vs str decode for a utf8 encoded byte string python 2 x                                                            |[python]         |
# |protecting javascript code in a ff extension                                                                               |[javascript]     |
# |how to return json from a 2 0 asmx web service                                                                             |null             |
# +---------------------------------------------------------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+---------+
# |input                                                                 |category |
# +----------------------------------------------------------------------+---------+
# |making an image greyscale with gd library                             |null     |
# |build tar file from directory in php without exec/passthru            |[php]    |
# |python beyond the basics                                              |[python] |
# |how do you deal with connection strings when deploying an asp net site|[asp.net]|
# |carbide / symbian c++ change application icon                         |[c++]    |
# |what is the best way to see what files are locked in subversion       |null     |
# |daemon threads explanation                                            |null     |
# |what design pattern to use for user authentication in java            |[java]   |
# |what s the term for design ala `` object method1 method2 method3 ``   |null     |
# |decoding chunked http with actionscript                               |null     |
# +----------------------------------------------------------------------+---------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------+-----------------+
# |input                                                                       |category         |
# +----------------------------------------------------------------------------+-----------------+
# |how do you deal with connection strings when deploying an asp net site      |[asp.net]        |
# |c # lambda expressions or delegates as a properties or arguments            |[c#]             |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]       |
# |suspending and notifying threads when there is work to do                   |[java, c#]       |
# |eclipse hide paths in the `` open resource '' dialog                        |null             |
# |class methods as event handlers in javascript                               |[javascript]     |
# |css `` see through '' background crazy navigation menu problem              |[asp.net]        |
# |parsing t sql to parameterize a query                                       |[sql, sql-server]|
# |how to serialize an object to xml without getting xmlns `` ``               |[c#]             |
# |in c # or any language what is/are your favourite way of removing repetition|[c#]             |
# +----------------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+--------------------------+
# |input                                                                                 |category                  |
# +--------------------------------------------------------------------------------------+--------------------------+
# |how can i change html attribute names with jquery                                     |[jquery, javascript, html]|
# |how do you manage infragistics webgrid data from javascript/ajax code                 |[c#]                      |
# |how to consume json web services from a windows client                                |[.net]                    |
# |how do i add custom column to existing wss list template                              |null                      |
# |how to pass an unpersisted modified object from view back to controller without a form|null                      |
# |creating my own iterators                                                             |[c#, .net]                |
# |sending email in net through gmail                                                    |[.net, c#, asp.net]       |
# |using lists in c #                                                                    |[c#]                      |
# |actionscript3 to javascript communication best practices                              |[javascript]              |
# |sql delete suspended in activity monitor                                              |[sql, sql-server]         |
# +--------------------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                                   |category              |
# +--------------------------------------------------------------------------------------------------------+----------------------+
# |c the definitive truth about rand random and arc4random                                                 |[c, c#]               |
# |how to effectively implement sessions in gae                                                            |null                  |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]     |
# |ms sql 2000 turn off logging during stored procedure                                                    |[sql-server, sql]     |
# |encoding problem classic asp                                                                            |[asp.net, asp.net-mvc]|
# |eclipse hide paths in the `` open resource '' dialog                                                    |null                  |
# |what is the aspnet_client folder for under the iis structure                                            |null                  |
# |daemon threads explanation                                                                              |null                  |
# |how do i extract the version and path from an svn working copy into a nant variable                     |null                  |
# |image archive vs image strip                                                                            |[css]                 |
# +--------------------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                                           |category              |
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |how to effectively implement sessions in gae                                                                    |null                  |
# |mac iwork/pages automation                                                                                      |null                  |
# |best way to use a db table as a message/job queue                                                               |[java]                |
# |daemon threads explanation                                                                                      |null                  |
# |stopping msi from launching an exe in the system context                                                        |[.net, c#]            |
# |specify ordinals of c++ exported functions in a dll                                                             |[c++]                 |
# |how can i convert my current page to pdf after some content dynamically added via ajax                          |[c#]                  |
# |html over flash without stopping interaction with flash                                                         |null                  |
# |asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|[asp.net-mvc, asp.net]|
# |uiwebview within a scrollview does not redraw                                                                   |null                  |
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
# +------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                     |category              |
# +------------------------------------------------------------------------------------------+----------------------+
# |python beyond the basics                                                                  |[python]              |
# |how does traceroute work                                                                  |[c#, .net]            |
# |implementing and enforcing coding standards                                               |[c++]                 |
# |how to generate unit test code for methods                                                |[java, c#]            |
# |encoding problem classic asp                                                              |[asp.net, asp.net-mvc]|
# |is it possible to define in a dependent dll s application config                          |[c#, .net]            |
# |is it true that the smallest memory allocation in net is a byte                           |[.net, c#]            |
# |rendered pixel width data for each character in a browser s font                          |null                  |
# |how do i fix a net webservice timeout causing a unsupportedmediaexception in a java client|[java]                |
# |is there an alternative for sleep in c                                                    |[c#, c]               |
# +------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+----------------------------------+
# |input                                                                                 |category                          |
# +--------------------------------------------------------------------------------------+----------------------------------+
# |whats the best way to start using mylyn                                               |[c#, .net]                        |
# |how do you deal with connection strings when deploying an asp net site                |[asp.net]                         |
# |how to pass an unpersisted modified object from view back to controller without a form|null                              |
# |sql query count with 0 count                                                          |[sql, sql-server, sql-server-2005]|
# |how to implement a singleton in c #                                                   |[c#]                              |
# |doctype rss & html entities                                                           |[html, asp.net, css]              |
# |how do i call net code c # /vb net from vbscript                                      |[c#, .net]                        |
# |eclipse hide paths in the `` open resource '' dialog                                  |null                              |
# |is there a way to asynchronously filter an ilist                                      |null                              |
# |be notified when visual/logical child added/removed                                   |[c#, c++]                         |
# +--------------------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------+--------------------+
# |input                                                     |category            |
# +----------------------------------------------------------+--------------------+
# |how can i send an array to php through ajax               |[php]               |
# |how do i add custom column to existing wss list template  |null                |
# |are incrementers / decrementers var++ var etc thread safe |[c++]               |
# |ms sql 2000 turn off logging during stored procedure      |[sql-server, sql]   |
# |c # in linux environment                                  |[c#]                |
# |converting svg to png using c #                           |[c#]                |
# |daemon threads explanation                                |null                |
# |is there a way to asynchronously filter an ilist          |null                |
# |vertical text with jquery                                 |[jquery, javascript]|
# |should i provide a deep clone when implementing icloneable|[java]              |
# +----------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------+-----------------------------------+
# |input                                                                |category                           |
# +---------------------------------------------------------------------+-----------------------------------+
# |should i have one class for every database i use                     |[java]                             |
# |the necessity of hiding the salt for a hash                          |[c++]                              |
# |while clause in t sql that loops forever                             |[sql, sql-server]                  |
# |image archive vs image strip                                         |[css]                              |
# |what s the term for design ala `` object method1 method2 method3 ``  |null                               |
# |which css tag creates a box like this with title                     |null                               |
# |authenticating against active directory with java on linux           |[java]                             |
# |visual studio 2005 stopped adding code behind files                  |[visual-studio, visual-studio-2008]|
# |not showing dialog when opening file in acrobat pro using applescript|[c#, .net]                         |
# |using boost shared_ptr in a library s public interface               |[c++]                              |
# +---------------------------------------------------------------------+-----------------------------------+
# only showing top 10 rows
#
# +--------------------------------------------------------+-------------------+
# |input                                                   |category           |
# +--------------------------------------------------------+-------------------+
# |is filestream lazy loaded in net                        |[.net, c#, asp.net]|
# |how do i add custom column to existing wss list template|null               |
# |how to effectively implement sessions in gae            |null               |
# |ms sql 2000 turn off logging during stored procedure    |[sql-server, sql]  |
# |how do you quickly find the url for a win32 api on msdn |null               |
# |db side encryption via nhibernate                       |null               |
# |eclipse text comparison order                           |[eclipse, java]    |
# |can you use an alias in the where clause in mysql       |[mysql]            |
# |setting the height of a div dynamically                 |[c#]               |
# |how can i determine the ip of my router/gateway in java |[java]             |
# +--------------------------------------------------------+-------------------+
# only showing top 10 rows
#
# +------------------------------------------------------------+--------------------+
# |input                                                       |category            |
# +------------------------------------------------------------+--------------------+
# |making an image greyscale with gd library                   |null                |
# |vector shape on stage appears over dynamic textfield        |null                |
# |mac iwork/pages automation                                  |null                |
# |how do you quickly find the url for a win32 api on msdn     |null                |
# |converting svg to png using c #                             |[c#]                |
# |what is the aspnet_client folder for under the iis structure|null                |
# |vertical text with jquery                                   |[jquery, javascript]|
# |creating my own iterators                                   |[c#, .net]          |
# |sending email in net through gmail                          |[.net, c#, asp.net] |
# |decoding chunked http with actionscript                     |null                |
# +------------------------------------------------------------+--------------------+
# only showing top 10 rows
# +--------------------------------------------------------------+---------------+
# |input                                                         |category       |
# +--------------------------------------------------------------+---------------+
# |getting odd error on net executenonquery                      |[.net, c#]     |
# |authoritative source on xml sig                               |[.net, php, c#]|
# |post from one controller action to another not redirect       |null           |
# |c # in linux environment                                      |[c#]           |
# |suspending and notifying threads when there is work to do     |[java, c#]     |
# |setting the height of a div dynamically                       |[c#]           |
# |how would you attack this polymorphism string building problem|[c#]           |
# |numbering regex submatches                                    |[php]          |
# |using lists in c #                                            |[c#]           |
# |decoding chunked http with actionscript                       |null           |
# +--------------------------------------------------------------+---------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+---------+
# |input                                                                                 |category |
# +--------------------------------------------------------------------------------------+---------+
# |c the definitive truth about rand random and arc4random                               |[c, c#]  |
# |prevent long word to add horizontal scroll to html view                               |[asp.net]|
# |how to pass an unpersisted modified object from view back to controller without a form|null     |
# |are incrementers / decrementers var++ var etc thread safe                             |[c++]    |
# |how can i get a list of available wireless networks on linux                          |[python] |
# |db side encryption via nhibernate                                                     |null     |
# |c # in linux environment                                                              |[c#]     |
# |ant and the available task what if something is not available                         |[java]   |
# |how do i calculate the previous business day in ksh shell script                      |null     |
# |what is the simplest way to find the difference between 2 times in python             |[python] |
# +--------------------------------------------------------------------------------------+---------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------------------+---------------------+
# |input                                                                          |category             |
# +-------------------------------------------------------------------------------+---------------------+
# |sql server and the guest account what is this for                              |[sql-server, sql]    |
# |should i have one class for every database i use                               |[java]               |
# |what is the best way to determine the number of days in a month with javascript|[javascript]         |
# |specify ordinals of c++ exported functions in a dll                            |[c++]                |
# |what are the limits of ruby on rails                                           |[ruby, ruby-on-rails]|
# |why is visual studio constantly crashing                                       |[visual-studio]      |
# |decoding chunked http with actionscript                                        |null                 |
# |what does it mean when a bug doesn t crash the program                         |[c++, java, c#]      |
# |http/ajax gwt vs eclipse gui for thin client deployment                        |[eclipse]            |
# |reading an xml file using fileinputstream for java                             |[java]               |
# +-------------------------------------------------------------------------------+---------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------+----------------+
# |input                                                                                         |category        |
# +----------------------------------------------------------------------------------------------+----------------+
# |prevent long word to add horizontal scroll to html view                                       |[asp.net]       |
# |carbide / symbian c++ change application icon                                                 |[c++]           |
# |why learn perl python ruby if the company is using c++ c # or java as the application language|[c++, c, python]|
# |what is the best way to determine the number of days in a month with javascript               |[javascript]    |
# |image archive vs image strip                                                                  |[css]           |
# |what s the term for design ala `` object method1 method2 method3 ``                           |null            |
# |why is visual studio constantly crashing                                                      |[visual-studio] |
# |what techniques can you use to profile your code                                              |[c#]            |
# |mvc preview 4 no route in the route table matches the supplied values                         |null            |
# |how to add a `` driver '' to javax comm serial port programming in java                       |[java]          |
# +----------------------------------------------------------------------------------------------+----------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------------------------------------------------------------------+----------------------------------+
# |input                                                                                                                      |category                          |
# +---------------------------------------------------------------------------------------------------------------------------+----------------------------------+
# |how can i change html attribute names with jquery                                                                          |[jquery, javascript, html]        |
# |how do i add custom column to existing wss list template                                                                   |null                              |
# |mac iwork/pages automation                                                                                                 |null                              |
# |sql query count with 0 count                                                                                               |[sql, sql-server, sql-server-2005]|
# |how do i call net code c # /vb net from vbscript                                                                           |[c#, .net]                        |
# |c # winforms datagridview/sql compact negative integer in primary key column                                               |[c#, .net]                        |
# |should db layer members be static or instance                                                                              |null                              |
# |can you set or where is the local document root                                                                            |[c#]                              |
# |anybody know why sql server 2005 throws `` sqloledb failed with no error message available result code e_fail 0x80004005 ``|[sql-server, sql]                 |
# |how do you maintain large t sql procedures                                                                                 |[sql, sql-server]                 |
# +---------------------------------------------------------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------+--------+
# |input                                                     |category|
# +----------------------------------------------------------+--------+
# |how can i send an array to php through ajax               |[php]   |
# |build tar file from directory in php without exec/passthru|[php]   |
# |game programming and event handlers                       |null    |
# |the necessity of hiding the salt for a hash               |[c++]   |
# |how do you quickly find the url for a win32 api on msdn   |null    |
# |db side encryption via nhibernate                         |null    |
# |eclipse hide paths in the `` open resource '' dialog      |null    |
# |how can i determine the ip of my router/gateway in java   |[java]  |
# |should i provide a deep clone when implementing icloneable|[java]  |
# |using lists in c #                                        |[c#]    |
# +----------------------------------------------------------+--------+
# only showing top 10 rows
# +-------------------------------------------------------------------------------+----------------------------------+
# |input                                                                          |category                          |
# +-------------------------------------------------------------------------------+----------------------------------+
# |sql server and the guest account what is this for                              |[sql-server, sql]                 |
# |prevent long word to add horizontal scroll to html view                        |[asp.net]                         |
# |is filestream lazy loaded in net                                               |[.net, c#, asp.net]               |
# |carbide / symbian c++ change application icon                                  |[c++]                             |
# |sql query count with 0 count                                                   |[sql, sql-server, sql-server-2005]|
# |suspending and notifying threads when there is work to do                      |[java, c#]                        |
# |ant and the available task what if something is not available                  |[java]                            |
# |what is the best way to determine the number of days in a month with javascript|[javascript]                      |
# |what s the term for design ala `` object method1 method2 method3 ``            |null                              |
# |how to serialize an object to xml without getting xmlns `` ``                  |[c#]                              |
# +-------------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +-----------------------------------------------------------------------+---------+
# |input                                                                  |category |
# +-----------------------------------------------------------------------+---------+
# |c # lambda expressions or delegates as a properties or arguments       |[c#]     |
# |c # in linux environment                                               |[c#]     |
# |best way to use a db table as a message/job queue                      |[java]   |
# |can you use an alias in the where clause in mysql                      |[mysql]  |
# |numbering regex submatches                                             |[php]    |
# |asp net users are logged out when deploying a new file to the server   |[asp.net]|
# |how to add a `` driver '' to javax comm serial port programming in java|[java]   |
# |sorting and grouping nested lists in python                            |[python] |
# |ddd and asynchronous repositories                                      |null     |
# |dropdownlist control with s for asp net webforms                       |[asp.net]|
# +-----------------------------------------------------------------------+---------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------+----------------------+
# |input                                                                                 |category              |
# +--------------------------------------------------------------------------------------+----------------------+
# |how do i add custom column to existing wss list template                              |null                  |
# ...
# |whats the best way to start using mylyn                                     |[c#, .net]                |
# |post from one controller action to another not redirect                     |null                      |
# |c # winforms datagridview/sql compact negative integer in primary key column|[c#, .net]                |
# |what is the aspnet_client folder for under the iis structure                |null                      |
# |what is the best way to see what files are locked in subversion             |null                      |
# |is there a way to asynchronously filter an ilist                            |null                      |
# |stopping msi from launching an exe in the system context                    |[.net, c#]                |
# +----------------------------------------------------------------------------+--------------------------+
# only showing top 10 rows
# +-----------------------------------------------------------------------------------+-----------+
# |input                                                                              |category   |
# +-----------------------------------------------------------------------------------+-----------+
# |making an image greyscale with gd library                                          |null       |
# |python beyond the basics                                                           |[python]   |
# |how do you deal with connection strings when deploying an asp net site             |[asp.net]  |
# |are incrementers / decrementers var++ var etc thread safe                          |[c++]      |
# |best way to use a db table as a message/job queue                                  |[java]     |
# |eclipse hide paths in the `` open resource '' dialog                               |null       |
# |how do i extract the version and path from an svn working copy into a nant variable|null       |
# |percentages of subtotal in a report                                                |[c++, java]|
# |creating my own iterators                                                          |[c#, .net] |
# |what s the term for design ala `` object method1 method2 method3 ``                |null       |
# +-----------------------------------------------------------------------------------+-----------+
# only showing top 10 rows
#
# +-------------------------------------------------------------------+------------+
# |input                                                              |category    |
# +-------------------------------------------------------------------+------------+
# |vector shape on stage appears over dynamic textfield               |null        |
# |game programming and event handlers                                |null        |
# |how can i get a list of available wireless networks on linux       |[python]    |
# |creating my own iterators                                          |[c#, .net]  |
# |image archive vs image strip                                       |[css]       |
# |class methods as event handlers in javascript                      |[javascript]|
# |what s the term for design ala `` object method1 method2 method3 ``|null        |
# |using lists in c #                                                 |[c#]        |
# |can you set or where is the local document root                    |[c#]        |
# |unix socket implementation for java                                |[java]      |
# +-------------------------------------------------------------------+------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------+-----------------+
# |input                                                           |category         |
# +----------------------------------------------------------------+-----------------+
# |whats the best way to start using mylyn                         |[c#, .net]       |
# |what is the aspnet_client folder for under the iis structure    |null             |
# |be notified when visual/logical child added/removed             |[c#, c++]        |
# |class methods as event handlers in javascript                   |[javascript]     |
# |parsing t sql to parameterize a query                           |[sql, sql-server]|
# |how to serialize an object to xml without getting xmlns `` ``   |[c#]             |
# |rendered pixel width data for each character in a browser s font|null             |
# |sorting and grouping nested lists in python                     |[python]         |
# |custom properties in xaml of system windows window              |[.net, c#]       |
# |how to do unit testing with uncertainties                       |[java]           |
# +----------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +------------------------------------------------------------------------+----------------------------------+
# |input                                                                   |category                          |
# +------------------------------------------------------------------------+----------------------------------+
# |making an image greyscale with gd library                               |null                              |
# |sql server and the guest account what is this for                       |[sql-server, sql]                 |
# |best update method for mysql db                                         |[mysql, sql, database]            |
# |sql query count with 0 count                                            |[sql, sql-server, sql-server-2005]|
# |how to disable visual studio macro `` tip '' balloon                    |[visual-studio]                   |
# |post from one controller action to another not redirect                 |null                              |
# |eclipse hide paths in the `` open resource '' dialog                    |null                              |
# |setting the height of a div dynamically                                 |[c#]                              |
# |what are the limits of ruby on rails                                    |[ruby, ruby-on-rails]             |
# |why is app_offline failing to work as soon as you it starts loading dlls|[.net, c#]                        |
# +------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
#
# +---------------------------------------------------------------+-----------------+
# |input                                                          |category         |
# +---------------------------------------------------------------+-----------------+
# |how to effectively implement sessions in gae                   |null             |
# |game programming and event handlers                            |null             |
# |while clause in t sql that loops forever                       |[sql, sql-server]|
# |how to generate unit test code for methods                     |[java, c#]       |
# |what design pattern to use for user authentication in java     |[java]           |
# |numbering regex submatches                                     |[php]            |
# |using lists in c #                                             |[c#]             |
# |authenticating against active directory with java on linux     |[java]           |
# |how do you maintain large t sql procedures                     |[sql, sql-server]|
# |does the iphone timeout if a function takes too long to execute|null             |
# +---------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# |input                                                                                                   |category                          |
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# |whats the best way to start using mylyn                                                                 |[c#, .net]                        |
# |vector shape on stage appears over dynamic textfield                                                    |null                              |
# |can sql server express be used to effectively administrate a sql server standard/enterprise installation|[sql-server, sql]                 |
# |sql query count with 0 count                                                                            |[sql, sql-server, sql-server-2005]|
# |how to disable visual studio macro `` tip '' balloon                                                    |[visual-studio]                   |
# |the necessity of hiding the salt for a hash                                                             |[c++]                             |
# |why learn perl python ruby if the company is using c++ c # or java as the application language          |[c++, c, python]                  |
# |can you use an alias in the where clause in mysql                                                       |[mysql]                           |
# |vertical text with jquery                                                                               |[jquery, javascript]              |
# |image archive vs image strip                                                                            |[css]                             |
# +--------------------------------------------------------------------------------------------------------+----------------------------------+
# only showing top 10 rows
# +---------------------------------------------------------------------------------------------------------------------------+--------------------+
# |input                                                                                                                      |category            |
# +---------------------------------------------------------------------------------------------------------------------------+--------------------+
# |the necessity of hiding the salt for a hash                                                                                |[c++]               |
# |c # lambda expressions or delegates as a properties or arguments                                                           |[c#]                |
# |best way to use a db table as a message/job queue                                                                          |[java]              |
# |is there a way to asynchronously filter an ilist                                                                           |null                |
# |should db layer members be static or instance                                                                              |null                |
# |how to serialize an object to xml without getting xmlns `` ``                                                              |[c#]                |
# |decoding chunked http with actionscript                                                                                    |null                |
# |anybody know why sql server 2005 throws `` sqloledb failed with no error message available result code e_fail 0x80004005 ``|[sql-server, sql]   |
# |2d javascript array                                                                                                        |[javascript, jquery]|
# |what does it mean when a bug doesn t crash the program                                                                     |[c++, java, c#]     |
# +---------------------------------------------------------------------------------------------------------------------------+--------------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------+-----------------+
# |input                                                                 |category         |
# +----------------------------------------------------------------------+-----------------+
# |sql server and the guest account what is this for                     |[sql-server, sql]|
# |how can i send an array to php through ajax                           |[php]            |
# |how do you deal with connection strings when deploying an asp net site|[asp.net]        |
# |how to effectively implement sessions in gae                          |null             |
# |how does traceroute work                                              |[c#, .net]       |
# |are incrementers / decrementers var++ var etc thread safe             |[c++]            |
# |how to implement a singleton in c #                                   |[c#]             |
# |ms sql 2000 turn off logging during stored procedure                  |[sql-server, sql]|
# |what is the best way to see what files are locked in subversion       |null             |
# |what design pattern to use for user authentication in java            |[java]           |
# +----------------------------------------------------------------------+-----------------+
# only showing top 10 rows
#
# +----------------------------------------------------------------+----------+
# |input                                                           |category  |
# +----------------------------------------------------------------+----------+
# |build tar file from directory in php without exec/passthru      |[php]     |
# |db side encryption via nhibernate                               |null      |
# |daemon threads explanation                                      |null      |
# |ant and the available task what if something is not available   |[java]    |
# |creating my own iterators                                       |[c#, .net]|
# |how do i focus a foreign window                                 |null      |
# |should db layer members be static or instance                   |null      |
# |stopping msi from launching an exe in the system context        |[.net, c#]|
# |how do i calculate the previous business day in ksh shell script|null      |
# |rendered pixel width data for each character in a browser s font|null      |
# +----------------------------------------------------------------+----------+
# only showing top 10 rows
#
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |input                                                                                                           |category              |
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# |sql server and the guest account what is this for                                                               |[sql-server, sql]     |
# |how to disable visual studio macro `` tip '' balloon                                                            |[visual-studio]       |
# |how do you quickly find the url for a win32 api on msdn                                                         |null                  |
# |c # in linux environment                                                                                        |[c#]                  |
# |is it true that the smallest memory allocation in net is a byte                                                 |[.net, c#]            |
# |what is the simplest way to find the difference between 2 times in python                                       |[python]              |
# |rendered pixel width data for each character in a browser s font                                                |null                  |
# |unix socket implementation for java                                                                             |[java]                |
# |sorting and grouping nested lists in python                                                                     |[python]              |
# |asp net mvc beta 1 defaultmodelbinder wrongly persists parameter and validation state between unrelated requests|[asp.net-mvc, asp.net]|
# +----------------------------------------------------------------------------------------------------------------+----------------------+
# only showing top 10 rows
#
# 438 ms ± 6.01 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
