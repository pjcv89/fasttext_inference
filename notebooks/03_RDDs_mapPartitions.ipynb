# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql import Row
import fasttext

# %%
spark = SparkSession.builder.master("local[4]").appName('mysession').getOrCreate()

# %% [markdown]
# ## Build Spark DataFrame

# %%
df_input = spark.read.parquet('../data/input.parquet').repartition(8)

# %% [markdown]
# # Approach 3: RDD's mapPartitions

# %%
def fn_partition(iterator,multi_prediction=False):
    
    def get_predictions(sentence, threshold=0.10, k=3):
        """
        Note: This is the same function as in classifier.py module!
        """
        labels, probs = model.predict(sentence.lower(), k=k)
        output = list(map(lambda y: y[0].replace("__label__", ""), filter(lambda x: x[1] >= threshold, zip(labels, probs))))
        if len(output) == 0:
            return None
        else:
            return output[0] if k == 1 else output
    
    model = fasttext.load_model('../models/ft_tuned.ftz')
    
    for record in iterator:
        if not multi_prediction:
            yield Row(category=get_predictions(record['input'],k=1),input=record['input'])
        else: 
            yield Row(category=get_predictions(record['input'],k=3),input=record['input'])

# %% [markdown]
# ## Single prediction

# %%
df_output = df_input.rdd.mapPartitions(lambda partition: fn_partition(partition,False)).toDF()
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +--------+---------------------------------------------------------------------------------------------+
# |category|input                                                                                        |
# +--------+---------------------------------------------------------------------------------------------+
# |null    |what deployment directories do you use for rails applications deploying to a debian box      |
# |sql     |sql query order by                                                                           |
# |c++     |c++ reading from a file blocks any further writing why                                       |
# |null    |how much does it cost to develop an iphone application                                       |
# |null    |what are some excellent examples of user sign up forms on the web                            |
# |.net    |why doesn t backcolor work for tabcontrols in net                                            |
# |c#      |c # compiler and caching of local variables                                                  |
# |c#      |is there a fast way to transfer all the variables of one identical object into another in c #|
# |c#      |filenotfound exception when using xmlserializer                                              |
# |flex    |iphone programming impressions opinions                                                      |
# +--------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# ## Multiple prediction

# %%
df_output = df_input.rdd.mapPartitions(lambda partition: fn_partition(partition,True)).toDF()
df_output.sample(False,.10,12345).show(10,False)
# Out:
# +-------------------+---------------------------------------------------------------------------------------------+
# |category           |input                                                                                        |
# +-------------------+---------------------------------------------------------------------------------------------+
# |null               |what deployment directories do you use for rails applications deploying to a debian box      |
# |[sql, sql-server]  |sql query order by                                                                           |
# |[c++]              |c++ reading from a file blocks any further writing why                                       |
# |null               |how much does it cost to develop an iphone application                                       |
# |null               |what are some excellent examples of user sign up forms on the web                            |
# |[.net, c#, asp.net]|why doesn t backcolor work for tabcontrols in net                                            |
# |[c#]               |c # compiler and caching of local variables                                                  |
# |[c#, .net]         |is there a fast way to transfer all the variables of one identical object into another in c #|
# |[c#, .net]         |filenotfound exception when using xmlserializer                                              |
# |[flex]             |iphone programming impressions opinions                                                      |
# +-------------------+---------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %% [markdown]
# # Performance

# %%
# %timeit -n 10 df_output.sample(False,.10).show(10)
# Out:
# +------------------+--------------------+
# |          category|               input|
# +------------------+--------------------+
# |            [.net]|what s the best w...|
# |              null|daemon threads ex...|
# |              null|compact framework...|
# |              null|is there an idiom...|
# |              [c#]|how can i convert...|
# |[java, javascript]|which javascript ...|
# |              [c#]|how to walk the m...|
# |             [php]|numbering regex s...|
# |   [java, eclipse]|how do you run an...|
# |        [c#, .net]|whats the best wa...|
# +------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how would you att...|
# |                null|cross platform ed...|
# |     [visual-studio]|how to script vis...|
# |           [asp.net]|prevent long word...|
# | [c#, .net, asp.net]|add multiple user...|
# | [.net, c#, asp.net]|implementing iint...|
# |          [c#, .net]|is endian convers...|
# |              [ruby]|why is rspec so s...|
# |   [sql, sql-server]|how can i filter ...|
# |[flash, silverlight]|    flash screenshot|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------+--------------------+
# |    category|               input|
# +------------+--------------------+
# |        [c#]|how would you att...|
# |[javascript]|how do you execut...|
# |        [c#]|download files to...|
# |      [java]|why do people use...|
# |      [java]|embedding xulrunn...|
# |   [asp.net]|prevent long word...|
# |      [java]|java stringbuffer...|
# |        null|transforming sele...|
# |  [c, mysql]|mysql c api using...|
# |   [windows]|are there problem...|
# +------------+--------------------+
# only showing top 10 rows
#
# +-----------------+--------------------+
# |         category|               input|
# +-----------------+--------------------+
# |             null|decoding chunked ...|
# |       [.net, c#]|persistent storag...|
# |     [javascript]|how do you execut...|
# |            [php]|random image pick...|
# |             [c#]|need help handlin...|
# |[sql-server, sql]|data verification...|
# |         [python]|how can i execute...|
# |             [c#]|c # compiler and ...|
# |       [c#, java]|equivalent of jav...|
# |       [c#, .net]|is there a fast w...|
# +-----------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |[mysql, sql, data...|best update metho...|
# |           [asp.net]|get performance c...|
# |                null|how to detect whe...|
# |     [.net, php, c#]|authoritative sou...|
# | [.net, c#, asp.net]|why doesn t backc...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |                [c#]|converting svg to...|
# |           [eclipse]|java date format ...|
# |               [c++]|using boost share...|
# |               [sql]|normalizing a tab...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------------+--------------------+
# |          category|               input|
# +------------------+--------------------+
# |        [java, c#]|deterministic dis...|
# |  [c++, c, python]|why learn perl py...|
# |             [c++]|the necessity of ...|
# |   [.net, php, c#]|authoritative sou...|
# |[java, javascript]|which javascript ...|
# |            [java]|java stringbuffer...|
# |              null|what s all this b...|
# |            [java]|what s the best w...|
# |              [c#]|c # compiler and ...|
# |              null|transforming sele...|
# +------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |          [c#, .net]|is it possible to...|
# |                null|ddd and asynchron...|
# |   [sql, sql-server]|  sql query order by|
# |               [c++]|the necessity of ...|
# |     [.net, php, c#]|authoritative sou...|
# |            [python]|how can i execute...|
# |[css, asp.net, html]|abstraction away ...|
# |          [c#, .net]|c # reflection ge...|
# |           [asp.net]|asp net ajax text...|
# |                null|transforming sele...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |               [c#]|how would you att...|
# |               null|tetris piece rota...|
# |       [sql-server]|sending e mail fr...|
# |            [mysql]|how do you connec...|
# |               [c#]|how to get the de...|
# |    [.net, php, c#]|authoritative sou...|
# |[c#, .net, asp.net]|what exception sh...|
# |          [asp.net]|edit html meta ta...|
# |          [asp.net]|prevent long word...|
# |          [asp.net]|asp net ajax text...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |    [visual-studio]|why is visual stu...|
# |               [c#]|how do you manage...|
# |               null|decoding chunked ...|
# |               null|what deployment d...|
# |               null|how do i open off...|
# |[c#, .net, asp.net]|what exception sh...|
# |          [asp.net]|edit html meta ta...|
# |               null|any good collecti...|
# |               null|where does rails ...|
# |               null|pexpect running s...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +------------+--------------------+
# |    category|               input|
# +------------+--------------------+
# |  [c#, .net]|is it possible to...|
# |[c, c#, c++]|wrapping visual c...|
# |        [c#]|how to serialize ...|
# |        null|daemon threads ex...|
# |        [c#]|how can i convert...|
# |        null|windows domain ch...|
# |        null|any good collecti...|
# |       [c++]|how to check if f...|
# |    [python]|get timer ticks i...|
# |    [python]|unicode vs str de...|
# +------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|cross platform ed...|
# |                null|running multiple ...|
# |                null|how to effectivel...|
# |[sql, sql-server,...|sql query count w...|
# | [c#, .net, asp.net]|what exception sh...|
# |           [asp.net]|prevent long word...|
# |          [c, mysql]|mysql c api using...|
# |                null|where does rails ...|
# |          [c#, .net]|filenotfound exce...|
# | [.net, c#, asp.net]|is filestream laz...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |           null|decoding chunked ...|
# |           null|what is the aspne...|
# |           null|running multiple ...|
# |      [asp.net]|get performance c...|
# |           null|how to detect whe...|
# |           null|apache/tomcat err...|
# |       [python]|need help variabl...|
# |          [php]|how can i send an...|
# |           null|db side encryptio...|
# |[java, eclipse]|how do you run an...|
# +---------------+--------------------+
# only showing top 10 rows
#
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |         [ruby]|similar thing to ...|
# |           null|decoding chunked ...|
# |     [c#, .net]|is it possible to...|
# |     [c#, .net]|drag n drop one o...|
# |           null|what s all this b...|
# |      [asp.net]|asp net ajax text...|
# |           null|transforming sele...|
# |         [ruby]|why is rspec so s...|
# |      [eclipse]|java date format ...|
# |[java, eclipse]|how do you run an...|
# +---------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|daemon threads ex...|
# |   [sql, sql-server]|  sql query order by|
# |     [visual-studio]|how to script vis...|
# |[sql, sql-server,...|sql query count w...|
# |                null|how much does it ...|
# |                null|apache/tomcat err...|
# |                [c#]|deployment of cus...|
# |          [c#, .net]|drag n drop one o...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |                null|where d my generi...|
# +--------------------+--------------------+
# only showing top 10 rows
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how would you att...|
# |                null|what deployment d...|
# |                null|compact framework...|
# |                [c#]|find a private fi...|
# |                null|what is the aspne...|
# |                null|is there an idiom...|
# |                null|what are some exc...|
# |                [c#]|how can i convert...|
# |                null|windows domain ch...|
# |[css, asp.net, html]|abstraction away ...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +----------+--------------------+
# |  category|               input|
# +----------+--------------------+
# |     [c++]|are incrementers ...|
# |[java, c#]|deterministic dis...|
# |      null|daemon threads ex...|
# |  [c++, c]|initialize a cons...|
# |      null|is there an idiom...|
# |     [c++]|c++ reading from ...|
# |      [c#]|  using lists in c #|
# |    [java]|embedding xulrunn...|
# | [asp.net]|prevent long word...|
# |     [php]|php $ _get sort p...|
# +----------+--------------------+
# only showing top 10 rows
#
# +-----------------+--------------------+
# |         category|               input|
# +-----------------+--------------------+
# |           [ruby]|similar thing to ...|
# |             [c#]|how would you att...|
# |             [c#]|how to serialize ...|
# |          [mysql]|how do you connec...|
# |             null|ddd and asynchron...|
# |[sql, sql-server]|  sql query order by|
# |  [eclipse, java]|eclipse text comp...|
# |[sql-server, sql]|data verification...|
# |             null|is there an idiom...|
# |            [c++]|the necessity of ...|
# +-----------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |              [ruby]|similar thing to ...|
# |               [c++]|are incrementers ...|
# |                [c#]|how do you manage...|
# |          [c#, .net]|is it possible to...|
# |                [c#]|how to get the de...|
# |                null|ddd and asynchron...|
# | [c#, .net, asp.net]|what exception sh...|
# |                null|windows domain ch...|
# |[css, asp.net, html]|abstraction away ...|
# |[visual-studio, ....|any have a visual...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------------+--------------------+
# |          category|               input|
# +------------------+--------------------+
# |      [c++, c#, c]|c++ odd compile e...|
# |              null|delphi project ne...|
# | [sql-server, sql]|data verification...|
# |         [asp.net]|get performance c...|
# |              null|what can cause in...|
# |[java, javascript]|which javascript ...|
# |              null|how do you quickl...|
# |              null|what s all this b...|
# |        [c#, java]|equivalent of jav...|
# |              null|transforming sele...|
# +------------------+--------------------+
# only showing top 10 rows
#
# +-----------------+--------------------+
# |         category|               input|
# +-----------------+--------------------+
# |  [visual-studio]|why is visual stu...|
# |             null|ddd and asynchron...|
# |            [php]|random image pick...|
# |[sql, sql-server]|  sql query order by|
# |             [c#]|find a private fi...|
# |  [visual-studio]|how to script vis...|
# |             null|is there an idiom...|
# |             null|how to effectivel...|
# |             [c#]|download files to...|
# |  [visual-studio]|visual studio fai...|
# +-----------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |          [java, c#]|deterministic dis...|
# |             [mysql]|how do you connec...|
# |                null|running multiple ...|
# |[html, asp.net, css]|doctype rss & htm...|
# |                null|how do i slice an...|
# | [.net, c#, asp.net]|implementing iint...|
# |          [c, mysql]|mysql c api using...|
# |                null|is it possible to...|
# |                null|regular expressio...|
# |[jquery, javascript]|pluggable edit co...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|how to disable vi...|
# |   [sql-server, sql]|data verification...|
# |                null|is there an idiom...|
# |                null|how much does it ...|
# |            [python]|need help variabl...|
# | [.net, c#, asp.net]|why doesn t backc...|
# |   [sql, sql-server]|parsing t sql to ...|
# |[visual-studio, ....|any have a visual...|
# |               [c++]|how to check if f...|
# |                null|fetch one row per...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |               null|what deployment d...|
# |               [c#]|how to serialize ...|
# |             [java]|trim whitespace f...|
# |               null|ddd and asynchron...|
# |  [sql-server, sql]|sql server profil...|
# |          [asp.net]|get performance c...|
# |               null|how to detect whe...|
# |               [c#]|how can i convert...|
# |[c#, .net, asp.net]|what exception sh...|
# |               null|windows domain ch...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|why is visual stu...|
# |[asp.net-mvc, asp...|asp net mvc beta ...|
# |          [c#, .net]|is it possible to...|
# |                null|cross platform ed...|
# |          [java, c#]|deterministic dis...|
# | [python, c++, java]|extracting text f...|
# |                null|ddd and asynchron...|
# |   [sql-server, sql]|data verification...|
# |           [asp.net]|get performance c...|
# |                null|apache/tomcat err...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |        [javascript]|how do you execut...|
# |                null|daemon threads ex...|
# |     [visual-studio]|how to script vis...|
# |                null|running multiple ...|
# |[sql, sql-server,...|sql query count w...|
# |     [visual-studio]|visual studio fai...|
# | [c#, .net, asp.net]|what exception sh...|
# |                null|windows domain ch...|
# | [.net, c#, asp.net]|why doesn t backc...|
# |   [sql, sql-server]|parsing t sql to ...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |           [c#]|how do you manage...|
# |           null|decoding chunked ...|
# |   [c++, c#, c]|c++ odd compile e...|
# |           null|ddd and asynchron...|
# |           null|daemon threads ex...|
# |           null|what is the aspne...|
# |           null|running multiple ...|
# |      [asp.net]|get performance c...|
# |[.net, php, c#]|authoritative sou...|
# |           null|what are some exc...|
# +---------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |          [.net, c#]|persistent storag...|
# |                null|tetris piece rota...|
# |        [c, c#, c++]|wrapping visual c...|
# |     [visual-studio]|how to script vis...|
# |            [python]|how can i execute...|
# |                null|transforming sele...|
# |              [ruby]|why is rspec so s...|
# |           [asp.net]|using server side...|
# |[sql-server, sql,...|how to justify mo...|
# |                null|release configura...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|why is visual stu...|
# |          [.net, c#]|persistent storag...|
# |[javascript, jquery]|weird ie & javasc...|
# |          [java, c#]|deterministic dis...|
# |     [eclipse, java]|eclipse text comp...|
# |                null|windows domain ch...|
# |[css, asp.net, html]|abstraction away ...|
# |            [python]|need help variabl...|
# |[visual-studio, ....|any have a visual...|
# |                null|fetch one row per...|
# +--------------------+--------------------+
# only showing top 10 rows
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |               [c++]|are incrementers ...|
# |        [c, c#, c++]|wrapping visual c...|
# |             [mysql]|how do you connec...|
# |                null|how do i open off...|
# |                null|running multiple ...|
# |                [c#]|deployment of cus...|
# |              [java]|why do people use...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |                null|how do you quickl...|
# |               [php]|virtual 360Ã¢Âº s...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |          [java, c#]|deterministic dis...|
# |                null|ddd and asynchron...|
# |[mysql, sql, data...|best update metho...|
# |               [c++]|the necessity of ...|
# |[sql, sql-server,...|sql query count w...|
# |            [python]|how can i execute...|
# |            [python]|need help variabl...|
# |              [java]|java stringbuffer...|
# |                [c#]|c # compiler and ...|
# |                [c#]|how to walk the m...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |               null|what deployment d...|
# |               null|cross platform ed...|
# |               [c#]|how to serialize ...|
# |               [c#]|how can i convert...|
# |[c#, .net, asp.net]|what exception sh...|
# |               null|how do i slice an...|
# |             [java]|what s the best w...|
# |         [c#, .net]|is it possible to...|
# |               null|pexpect running s...|
# |               null|db side encryptio...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |           null|what deployment d...|
# |           null|cross platform ed...|
# |     [java, c#]|deterministic dis...|
# |   [sql-server]|sending e mail fr...|
# |           null|how do i open off...|
# |           [c#]|find a private fi...|
# |[visual-studio]|how to script vis...|
# |           [c#]|deployment of cus...|
# |         [java]|embedding xulrunn...|
# |          [php]|virtual 360Ã¢Âº s...|
# +---------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|how to disable vi...|
# |                null|decoding chunked ...|
# |[javascript, jquery]|weird ie & javasc...|
# |                [c#]|how to serialize ...|
# |              [java]|trim whitespace f...|
# |             [mysql]|how do you connec...|
# |     [visual-studio]|how to script vis...|
# |[mysql, sql, data...|best update metho...|
# |           [asp.net]|get performance c...|
# |                null|windows domain ch...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|tetris piece rota...|
# |                null|daemon threads ex...|
# |[mysql, sql, data...|best update metho...|
# |     [.net, php, c#]|authoritative sou...|
# |                null|windows domain ch...|
# |                null|how do you quickl...|
# |              [java]|java stringbuffer...|
# |                null|how should i impo...|
# |                null|where does rails ...|
# |          [c#, .net]|filenotfound exce...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +----------+--------------------+
# |  category|               input|
# +----------+--------------------+
# |      [c#]|how to get the de...|
# |      [c#]|how do you bind i...|
# |  [c++, c]|initialize a cons...|
# |      null|running multiple ...|
# |      null|is there an idiom...|
# |  [python]|get timer ticks i...|
# |[c, mysql]|mysql c api using...|
# |      null|has and belongs t...|
# |      null|how do i deploy a...|
# |[.net, c#]|is it true that t...|
# +----------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |[asp.net-mvc, asp...|asp net mvc beta ...|
# |          [.net, c#]|persistent storag...|
# |        [sql-server]|sending e mail fr...|
# |                [c#]|how to get the de...|
# |                null|daemon threads ex...|
# |                null|compact framework...|
# |            [c++, c]|initialize a cons...|
# |   [sql-server, sql]|sql server profil...|
# |[sql, sql-server,...|sql query count w...|
# |            [python]|how can i execute...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |               null|what deployment d...|
# |             [java]|why don t my html...|
# |  [sql-server, sql]|data verification...|
# |               null|running multiple ...|
# |              [c++]|the necessity of ...|
# |[c#, .net, asp.net]|what exception sh...|
# |              [php]|virtual 360Ã¢Âº s...|
# |              [c++]|determine if type...|
# |               null|transforming sele...|
# |         [c#, .net]|is there a fast w...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |             [java]|why don t my html...|
# |       [javascript]|how do you execut...|
# |[python, c++, java]|extracting text f...|
# |   [c++, c, python]|why learn perl py...|
# |               [c#]|download files to...|
# |[.net, c#, asp.net]|why doesn t backc...|
# |               null|transforming sele...|
# |         [c#, .net]|is there a fast w...|
# |           [python]|unicode vs str de...|
# |         [c#, .net]|filenotfound exce...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|why is visual stu...|
# |                null|cross platform ed...|
# |              [java]|trim whitespace f...|
# |                [c#]|how to get the de...|
# | [c#, .net, asp.net]|what exception sh...|
# |                null|windows domain ch...|
# |                null|what can cause in...|
# |[html, asp.net, css]|doctype rss & htm...|
# |          [c#, .net]|drag n drop one o...|
# |   [sql, sql-server]|parsing t sql to ...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------------+--------------------+
# |          category|               input|
# +------------------+--------------------+
# |              null|decoding chunked ...|
# |   [eclipse, java]|eclipse text comp...|
# |              null|what is the aspne...|
# |             [c++]|c++ reading from ...|
# |              null|what can cause in...|
# |        [c#, .net]|drag n drop one o...|
# |[java, javascript]|which javascript ...|
# |              null|how do i slice an...|
# |              [c#]|c # compiler and ...|
# |            [java]|saving java objec...|
# +------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |               [c++]|are incrementers ...|
# |              [java]|trim whitespace f...|
# |                null|ddd and asynchron...|
# |                null|how do i open off...|
# |                null|what is the aspne...|
# |                null|how to effectivel...|
# |    [c++, c, python]|why learn perl py...|
# |               [c++]|c++ reading from ...|
# |                [c#]|  using lists in c #|
# |[visual-studio, ....|any have a visual...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how would you att...|
# | [python, c++, java]|extracting text f...|
# |               [php]|random image pick...|
# |                null|what is the aspne...|
# |     [visual-studio]|how to script vis...|
# |    [c++, c, python]|why learn perl py...|
# |[sql, sql-server,...|sql query count w...|
# | [c#, .net, asp.net]|what exception sh...|
# |                null|windows domain ch...|
# |                null|apache/tomcat err...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|decoding chunked ...|
# |          [java, c#]|deterministic dis...|
# |             [mysql]|how do you connec...|
# |                [c#]|how do you bind i...|
# |    [c++, c, python]|why learn perl py...|
# |                [c#]|how can i convert...|
# |                null|windows domain ch...|
# |                null|what can cause in...|
# |           [asp.net]|edit html meta ta...|
# |[ruby, ruby-on-ra...|what are the limi...|
# +--------------------+--------------------+
# only showing top 10 rows
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |             [mysql]|how do you connec...|
# |                [c#]|find a private fi...|
# |                null|running multiple ...|
# |           [asp.net]|get performance c...|
# |                null|how to effectivel...|
# |    [c++, c, python]|why learn perl py...|
# |[sql, sql-server,...|sql query count w...|
# |     [visual-studio]|visual studio fai...|
# |            [python]|how can i execute...|
# |                null|any good collecti...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |              [.net]|what s the best w...|
# | [python, c++, java]|extracting text f...|
# |   [sql-server, sql]|sql server profil...|
# |                null|what are some exc...|
# |     [visual-studio]|visual studio fai...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |               [php]|virtual 360Ã¢Âº s...|
# |                [c#]|c # compiler and ...|
# |                [c#]|how to walk the m...|
# |                null|transforming sele...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|decoding chunked ...|
# |          [java, c#]|deterministic dis...|
# |                [c#]|how do you bind i...|
# |                null|how to effectivel...|
# |                null|what are some exc...|
# |                [c#]|deployment of cus...|
# |                null|how do you quickl...|
# |                null|how do i slice an...|
# |[asp.net, asp.net...|what are effectiv...|
# |          [c, mysql]|mysql c api using...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------+--------------------+
# |    category|               input|
# +------------+--------------------+
# |      [.net]|what s the best w...|
# |[c++, c#, c]|c++ odd compile e...|
# |        null|delphi project ne...|
# |     [mysql]|how do you connec...|
# |        [c#]|how to get the de...|
# |        null|is there an idiom...|
# |        null|how to effectivel...|
# |        null|how to detect whe...|
# |        [c#]|how can i convert...|
# |        null|windows domain ch...|
# +------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|what is the aspne...|
# |     [.net, php, c#]|authoritative sou...|
# |     [visual-studio]|visual studio fai...|
# |           [asp.net]|edit html meta ta...|
# |            [python]|need help variabl...|
# | [c#, .net, asp.net]|add multiple user...|
# |[asp.net, asp.net...|what are effectiv...|
# |          [c#, java]|equivalent of jav...|
# |                [c#]|how to walk the m...|
# | [.net, c#, asp.net]|is filestream laz...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |         [java, c#]|deterministic dis...|
# |               [c#]|how to serialize ...|
# |               [c#]|download files to...|
# |    [visual-studio]|visual studio fai...|
# |           [python]|how can i execute...|
# |               null|apache/tomcat err...|
# |           [python]|need help variabl...|
# |          [asp.net]|asp net ajax text...|
# |[.net, c#, asp.net]|implementing iint...|
# |               null|where does rails ...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |               null|daemon threads ex...|
# |               null|how to effectivel...|
# |              [c++]|c++ reading from ...|
# |             [java]|java stringbuffer...|
# |[c#, .net, asp.net]|add multiple user...|
# |               null|where d my generi...|
# |               null|how do i slice an...|
# |               null|vs2008 ide giving...|
# |               null|fetch one row per...|
# |          [eclipse]|java date format ...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how would you att...|
# |                null|what is the aspne...|
# |                null|is there an idiom...|
# |                null|windows domain ch...|
# |           [asp.net]|edit html meta ta...|
# |[visual-studio, ....|any have a visual...|
# |   [sql, sql-server]|how can i filter ...|
# |                null|is it possible to...|
# |                null|what s the maximu...|
# |                null|db side encryptio...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |              [c++]|are incrementers ...|
# |         [.net, c#]|persistent storag...|
# |               [c#]|how to serialize ...|
# |[python, c++, java]|extracting text f...|
# |    [visual-studio]|how to script vis...|
# |              [c++]|c++ reading from ...|
# |               null|code golf combini...|
# |           [python]|how can i execute...|
# |          [asp.net]|edit html meta ta...|
# |               null|how do you quickl...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +------------------+--------------------+
# |          category|               input|
# +------------------+--------------------+
# |              null|tetris piece rota...|
# |      [sql-server]|sending e mail fr...|
# |          [python]|how can i execute...|
# |         [asp.net]|edit html meta ta...|
# |[java, javascript]|which javascript ...|
# |        [c#, .net]|c # reflection ge...|
# |              null|what s all this b...|
# |             [c++]|how to check if f...|
# |             [php]|virtual 360Ã¢Âº s...|
# |        [c#, .net]|is it possible to...|
# +------------------+--------------------+
# only showing top 10 rows
#
# +-----------------+--------------------+
# |         category|               input|
# +-----------------+--------------------+
# |     [javascript]|how do you execut...|
# |  [visual-studio]|how to script vis...|
# |             null|how to effectivel...|
# |             null|how to detect whe...|
# |  [.net, php, c#]|authoritative sou...|
# |             null|windows domain ch...|
# |             [c#]|deployment of cus...|
# |[sql, sql-server]|parsing t sql to ...|
# |             null|what s all this b...|
# |             null|any good collecti...|
# +-----------------+--------------------+
# only showing top 10 rows
#
# +----------+--------------------+
# |  category|               input|
# +----------+--------------------+
# |      null|decoding chunked ...|
# |      null|what deployment d...|
# |      null|code golf combini...|
# |[c#, .net]|c # reflection ge...|
# |    [java]|java stringbuffer...|
# | [asp.net]|asp net ajax text...|
# |    [java]|what s the best w...|
# |[c#, .net]|is it possible to...|
# |      [c#]|converting svg to...|
# |     [php]|how can i send an...|
# +----------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|delphi project ne...|
# |               [c++]|c++ reading from ...|
# | [.net, c#, asp.net]|why doesn t backc...|
# |           [asp.net]|prevent long word...|
# |               [php]|virtual 360Ã¢Âº s...|
# |          [c#, .net]|is endian convers...|
# |                null|db side encryptio...|
# |                null|what is the best ...|
# |                null|regular expressio...|
# |[jquery, javascript]|pluggable edit co...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |    [visual-studio]|why is visual stu...|
# |    [eclipse, java]|eclipse text comp...|
# |               null|is there an idiom...|
# |   [c++, c, python]|why learn perl py...|
# |    [visual-studio]|visual studio fai...|
# |         [c#, .net]|c # reflection ge...|
# |          [asp.net]|prevent long word...|
# |[c#, .net, asp.net]|add multiple user...|
# |               null|where d my generi...|
# |               null|how do i slice an...|
# +-------------------+--------------------+
# only showing top 10 rows
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |   [c, c#, c++]|wrapping visual c...|
# |         [java]|trim whitespace f...|
# |      [asp.net]|get performance c...|
# |[.net, php, c#]|authoritative sou...|
# |           null|windows domain ch...|
# |           null|what can cause in...|
# |          [php]|virtual 360Ã¢Âº s...|
# |     [c#, .net]|is it possible to...|
# |           null|can i use css in ...|
# |          [sql]|normalizing a tab...|
# +---------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how do you manage...|
# |     [visual-studio]|how to disable vi...|
# |                null|what deployment d...|
# |              [java]|trim whitespace f...|
# |                null|what is the aspne...|
# |                [c#]|download files to...|
# |                null|apache/tomcat err...|
# |[asp.net, asp.net...|what are effectiv...|
# |          [c#, .net]|is it possible to...|
# |          [c#, .net]|is endian convers...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|how to disable vi...|
# |                null|is there an idiom...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |                null|what s all this b...|
# |              [ruby]|why is rspec so s...|
# |                [c#]|converting svg to...|
# |                null|is it possible to...|
# |              [flex]|iphone programmin...|
# |                null|can i use css in ...|
# |              [java]|better way of ret...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |          [java, c#]|deterministic dis...|
# |        [sql-server]|sending e mail fr...|
# |                null|daemon threads ex...|
# |                null|compact framework...|
# |     [visual-studio]|visual studio fai...|
# |          [c#, .net]|is it possible to...|
# |               [php]|numbering regex s...|
# |                null|what s the maximu...|
# |[jquery, javascript]|pluggable edit co...|
# |          [c#, .net]|whats the best wa...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-----------------+--------------------+
# |         category|               input|
# +-----------------+--------------------+
# |             null|decoding chunked ...|
# |             [c#]|need help handlin...|
# |  [eclipse, java]|eclipse text comp...|
# |[sql-server, sql]|data verification...|
# |[sql-server, sql]|sql server profil...|
# |           [java]|why do people use...|
# |            [c++]|how to check if f...|
# |       [c, mysql]|mysql c api using...|
# |        [windows]|are there problem...|
# |             null|has and belongs t...|
# +-----------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                null|subsonic subsonic...|
# |[html, asp.net, css]|doctype rss & htm...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |[visual-studio, ....|any have a visual...|
# | [c#, .net, asp.net]|add multiple user...|
# |                null|any good collecti...|
# |           [asp.net]|asp net ajax text...|
# |          [c#, java]|equivalent of jav...|
# |                [c#]|converting svg to...|
# | [.net, c#, asp.net]|is filestream laz...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +------------+--------------------+
# |    category|               input|
# +------------+--------------------+
# |      [.net]|what s the best w...|
# |      [java]|why don t my html...|
# |[c++, c#, c]|c++ odd compile e...|
# |  [java, c#]|deterministic dis...|
# |        [c#]|how to get the de...|
# |        null|is there an idiom...|
# |        null|code golf combini...|
# |        null|apache/tomcat err...|
# |        null|where d my generi...|
# |        null|bat file to run a...|
# +------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |               [c++]|are incrementers ...|
# |        [sql-server]|sending e mail fr...|
# |                null|ddd and asynchron...|
# |                [c#]|need help handlin...|
# |                null|running multiple ...|
# |            [python]|need help variabl...|
# |          [c#, .net]|drag n drop one o...|
# |[ruby, ruby-on-ra...|what are the limi...|
# |                null|bat file to run a...|
# |          [c#, java]|equivalent of jav...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |     [visual-studio]|why is visual stu...|
# | [python, c++, java]|extracting text f...|
# |     [eclipse, java]|eclipse text comp...|
# |[mysql, sql, data...|best update metho...|
# |    [c++, c, python]|why learn perl py...|
# |                null|what s all this b...|
# |                null|where d my generi...|
# |          [c#, .net]|is there a fast w...|
# |           [windows]|are there problem...|
# |                null|db side encryptio...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |       [c++, c#, c]|c++ odd compile e...|
# |       [c, c#, c++]|wrapping visual c...|
# |               [c#]|how to serialize ...|
# |               [c#]|need help handlin...|
# |               null|how to effectivel...|
# |[.net, c#, asp.net]|why doesn t backc...|
# |         [c, mysql]|mysql c api using...|
# |              [php]|php $ _get sort p...|
# |               null|can i use css in ...|
# |             [java]|better way of ret...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +--------------------+--------------------+
# |            category|               input|
# +--------------------+--------------------+
# |                [c#]|how do you manage...|
# |              [.net]|what s the best w...|
# |                [c#]|how to serialize ...|
# |                [c#]|how do you bind i...|
# |            [c++, c]|initialize a cons...|
# |[mysql, sql, data...|best update metho...|
# |                null|running multiple ...|
# |    [c++, c, python]|why learn perl py...|
# |     [.net, php, c#]|authoritative sou...|
# |[sql, sql-server,...|sql query count w...|
# +--------------------+--------------------+
# only showing top 10 rows
#
# +-------------------+--------------------+
# |           category|               input|
# +-------------------+--------------------+
# |             [.net]|what s the best w...|
# |         [.net, c#]|persistent storag...|
# |       [javascript]|how do you execut...|
# |  [sql-server, sql]|data verification...|
# |[.net, c#, asp.net]|why doesn t backc...|
# |         [c#, .net]|c # reflection ge...|
# |             [java]|embedding xulrunn...|
# |              [c++]|determine if type...|
# |             [java]|saving java objec...|
# |              [php]|how can i send an...|
# +-------------------+--------------------+
# only showing top 10 rows
#
# +---------------+--------------------+
# |       category|               input|
# +---------------+--------------------+
# |[visual-studio]|why is visual stu...|
# |[visual-studio]|how to disable vi...|
# |           null|decoding chunked ...|
# |           null|delphi project ne...|
# |     [java, c#]|deterministic dis...|
# |        [mysql]|how do you connec...|
# |           [c#]|how to get the de...|
# |       [python]|need help variabl...|
# |           [c#]|  using lists in c #|
# |           null|fetch one row per...|
# +---------------+--------------------+
# only showing top 10 rows
#
# 212 ms ± 21.2 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df_output.rdd.getNumPartitions()
# Out:
# 8
